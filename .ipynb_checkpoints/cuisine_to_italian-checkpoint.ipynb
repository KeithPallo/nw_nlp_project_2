# %%
import pandas as pd
import nltk
import re
import string
from collections import Counter
import json

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# %%
from parse_url import *
from mapping_urls_make import *

# %%
def get_test_ingredients(og_ingredients):
    test_ingredients = [x['name'] for x in og_ingredients]
    
    return test_ingredients

# %%
def clean_text(s):
    s = re.sub("[^a-zA-Z ]", ' ', s)
    s = s.lower()
    s = word_tokenize(s)
    
    # filter out stop words
    words = [w for w in s if not w in stop_words]
    
    return words

# %%
def get_italian_ingredients(all_recipes):
    cuisine_df = pd.read_json(all_recipes)
    italian_df = cuisine_df[cuisine_df['cuisine'] == 'italian']
    
    italian = []
    #print(italian_df['ingredients'].tolist())
    for i in italian_df['ingredients'].tolist():
        for j in i:
            #print(j)
            italian.append(j)
            
    return italian

# %%
temp = get_italian_ingredients('train.json')

# %%
temp
# Out:
# ['sugar',
#  'pistachio nuts',
#  'white almond bark',
#  'flour',
#  'vanilla extract',
#  'olive oil',
#  'almond extract',
#  'eggs',
#  'baking powder',
#  'dried cranberries',
#  'chopped tomatoes',
#  'fresh basil',
#  'garlic',
#  'extra-virgin olive oil',
#  'kosher salt',
#  'flat leaf parsley',
#  'pimentos',
#  'sweet pepper',
#  'dried oregano',
#  'olive oil',
#  'garlic',
#  'sharp cheddar cheese',
#  'pepper',
#  'swiss cheese',
#  'provolone cheese',
#  'canola oil',
#  'mushrooms',
#  'black olives',
#  'sausages',
#  'Italian parsley leaves',
#  'walnuts',
#  'hot red pepper flakes',
#  'extra-virgin olive oil',
#  'fresh lemon juice',
#  'trout fillet',
#  'garlic cloves',
#  'chipotle chile',
#  'fine sea salt',
#  'flat leaf parsley',
#  'fresh parmesan cheese',
#  'butter',
#  'all-purpose flour',
#  'fat free less sodium chicken broth',
#  'chopped fresh chives',
#  'gruyere cheese',
#  'ground black pepper',
#  'bacon slices',
#  'gnocchi',
#  'fat free milk',
#  'cooking spray',
#  'salt',
#  'italian seasoning',
#  'broiler-fryer chicken',
#  'mayonaise',
#  'zesty italian dressing',
#  'marinara sauce',
#  'flat leaf parsley',
#  'olive oil',
#  'linguine',
#  'capers',
#  'crushed red pepper flakes',
#  'olives',
#  'lemon zest',
#  'garlic',
#  'ground black pepper',
#  'butter',
#  'sliced mushrooms',
#  'sherry',
#  'salt',
#  'grated parmesan cheese',
#  'heavy cream',
#  'spaghetti',
#  'chicken broth',
#  'cooked chicken',
#  'all-purpose flour',
#  'yellow corn meal',
#  'boiling water',
#  'butter',
#  'fresh parmesan cheese',
#  'sea salt',
#  'olive oil',
#  'onions',
#  'crushed garlic',
#  'dried oregano',
#  'green onions',
#  'white sugar',
#  'dried basil',
#  'diced tomatoes',
#  'olive oil',
#  'bread slices',
#  'great northern beans',
#  'garlic cloves',
#  'pepper',
#  'shrimp',
#  'sage leaves',
#  'salt',
#  'Oscar Mayer Deli Fresh Smoked Ham',
#  'hoagie rolls',
#  'salami',
#  'giardiniera',
#  'mozzarella cheese',
#  'pepperoni',
#  'butter',
#  'italian seasoning',
#  'fresh basil',
#  'bay leaves',
#  'crushed red pepper',
#  'mussels',
#  'olive oil',
#  'basil',
#  'garlic cloves',
#  'black pepper',
#  'dry white wine',
#  'salt',
#  'tomatoes',
#  'finely chopped onion',
#  'linguine',
#  'flat leaf parsley',
#  'lemon',
#  'pesto',
#  'salmon fillets',
#  'white wine',
#  'pizza crust',
#  'plum tomatoes',
#  'pesto',
#  'part-skim mozzarella cheese',
#  'crushed tomatoes',
#  'garlic',
#  'fresh rosemary',
#  'ground black pepper',
#  'onions',
#  'olive oil',
#  'boneless pork loin',
#  'kosher salt',
#  'pappardelle',
#  'tomatoes',
#  'red pepper',
#  'olive oil',
#  'Italian bread',
#  'balsamic vinegar',
#  'onions',
#  'fresh basil',
#  'garlic',
#  'sausage casings',
#  'ground black pepper',
#  'garlic',
#  'honey',
#  'grated parmesan cheese',
#  'shredded mozzarella cheese',
#  'kosher salt',
#  'roasted red peppers',
#  'penne pasta',
#  'olive oil',
#  'crushed red pepper flakes',
#  'spinach',
#  'asiago',
#  'whole wheat pasta',
#  'olive oil',
#  'sweet onion',
#  'garlic',
#  'grape tomatoes',
#  'mushrooms',
#  'chestnuts',
#  'granulated sugar',
#  'whole milk ricotta cheese',
#  'coffee ice cream',
#  'large eggs',
#  'mascarpone',
#  'rum',
#  'powdered sugar',
#  'semisweet chocolate',
#  'chestnut flour',
#  'salt',
#  'starchy potatoes',
#  'grated nutmeg',
#  'flour',
#  'olive oil',
#  'olives',
#  'salt',
#  'blood orange',
#  'freshly ground pepper',
#  'fennel bulb',
#  'balsamic vinegar',
#  'low salt chicken broth',
#  'dijon mustard',
#  'corn starch',
#  'dried basil',
#  'garlic cloves',
#  'white wine vinegar',
#  'tomato sauce',
#  'shredded carrots',
#  'spinach',
#  'part-skim mozzarella cheese',
#  'italian seasoning',
#  'english muffins, split and toasted',
#  'chopped onion',
#  'vegetable oil cooking spray',
#  'chopped green bell pepper',
#  'cheddar cheese',
#  'lasagna noodles',
#  'pepper',
#  'ranch dressing',
#  'mozzarella cheese',
#  'cooked chicken',
#  'evaporated milk',
#  'olive oil',
#  'freshly ground pepper',
#  'fresh rosemary',
#  'salt',
#  'fresh parsley',
#  'fresh basil',
#  'fresh oregano',
#  'crushed red pepper',
#  'garlic cloves',
#  'cold water',
#  'sugar',
#  'butter',
#  'chocolate morsels',
#  'cream sweeten whip',
#  'instant espresso granules',
#  'whipping cream',
#  'boiling water',
#  'kahlúa',
#  'large eggs',
#  'chocolate covered coffee beans',
#  'unflavored gelatin',
#  'mascarpone',
#  'pound cake',
#  'pinenuts',
#  'zucchini',
#  'baby carrots',
#  'fresh basil leaves',
#  'olive oil',
#  'dry white wine',
#  'asparagus spears',
#  'white onion',
#  'grated parmesan cheese',
#  'carrots',
#  'frozen peas',
#  'arborio rice',
#  'yellow crookneck squash',
#  'butter',
#  'low salt chicken broth',
#  'fresh leav spinach',
#  'cheese tortellini',
#  'fresh basil',
#  'cherry tomatoes',
#  'fresh lemon juice',
#  'capers',
#  'fresh parmesan cheese',
#  'navy beans',
#  'pepper',
#  'extra-virgin olive oil',
#  'pecorino romano cheese',
#  'fresh fava bean',
#  'finely chopped onion',
#  'extra-virgin olive oil',
#  'plum tomatoes',
#  'italian sausage',
#  'large garlic cloves',
#  'pasta sheets',
#  'dry white wine',
#  'crushed red pepper',
#  'shredded mozzarella cheese',
#  'marinara sauce',
#  'fresh basil leaves',
#  'penne pasta',
#  'water',
#  'extra-virgin olive oil',
#  'carrots',
#  'hot red pepper flakes',
#  'Turkish bay leaves',
#  'dried chickpeas',
#  'onions',
#  'celery ribs',
#  'semolina',
#  'fine sea salt',
#  'flat leaf parsley',
#  'warm water',
#  'vine ripened tomatoes',
#  'garlic cloves',
#  'sugar',
#  'mascarpone',
#  'bittersweet chocolate',
#  'fat free yogurt',
#  'vanilla extract',
#  'skim milk',
#  'angel food cake',
#  'unsweetened cocoa powder',
#  'kahlúa',
#  'water',
#  'instant espresso',
#  'diced tomatoes',
#  'sugar',
#  'garlic salt',
#  'tomato paste',
#  'crushed red pepper',
#  'dried basil',
#  'dried oregano',
#  'mushrooms',
#  'all-purpose flour',
#  'fresh rosemary',
#  'veal cutlets',
#  'plum tomatoes',
#  'dry white wine',
#  'low salt chicken broth',
#  'olive oil',
#  'large garlic cloves',
#  'hot red pepper flakes',
#  'broccoli rabe',
#  'whole milk',
#  'garlic cloves',
#  'black pepper',
#  'parmigiano reggiano cheese',
#  'all-purpose flour',
#  'sausage casings',
#  'olive oil',
#  'large eggs',
#  'dry bread crumbs',
#  'fontina',
#  'unsalted butter',
#  'salt',
#  'pasta sauce',
#  'fresh parmesan cheese',
#  'olive oil flavored cooking spray',
#  'frozen chopped spinach',
#  'large egg whites',
#  'part-skim ricotta cheese',
#  'pepper',
#  'large eggs',
#  'italian seasoning',
#  'manicotti shells',
#  'part-skim mozzarella cheese',
#  'salt',
#  'vegetable oil cooking spray',
#  'dry white wine',
#  'sliced mushrooms',
#  'fettucine',
#  'olive oil',
#  'fresh oregano',
#  'onions',
#  'fresh basil',
#  'parmesan cheese',
#  'corn starch',
#  'large shrimp',
#  'tomatoes',
#  'chicken bouillon',
#  'garlic',
#  'flat leaf parsley',
#  'cream of tartar',
#  'pistachio nuts',
#  'salt',
#  'orange liqueur',
#  'eggs',
#  'vanilla extract',
#  'heavy whipping cream',
#  'semi-sweet chocolate morsels',
#  'water',
#  'cake flour',
#  'confectioners sugar',
#  'ground cinnamon',
#  'ricotta cheese',
#  'cream cheese',
#  'white sugar',
#  'dried porcini mushrooms',
#  'chopped fresh thyme',
#  'beef rib short',
#  'tomato paste',
#  'kosher salt',
#  'dry red wine',
#  'hot water',
#  'black pepper',
#  'fat free less sodium beef broth',
#  'garlic cloves',
#  'cremini mushrooms',
#  'olive oil',
#  'all-purpose flour',
#  'onions',
#  'pitted kalamata olives',
#  'grated parmesan cheese',
#  'penne pasta',
#  'cauliflower',
#  'olive oil',
#  'crushed red pepper',
#  'pepper',
#  'garlic',
#  'fresh parsley',
#  'capers',
#  'whole peeled tomatoes',
#  'salt',
#  'swiss chard',
#  'diced tomatoes',
#  'chopped onion',
#  'pepper',
#  'banana squash',
#  'garlic',
#  'italian seasoning',
#  'grated parmesan cheese',
#  'vegetable broth',
#  'bay leaf',
#  'olive oil',
#  'cannellini beans',
#  'salt',
#  'ground black pepper',
#  'fresh parsley',
#  'fat free less sodium chicken broth',
#  'salt',
#  'capers',
#  'balsamic vinegar',
#  'boneless skinless chicken breast halves',
#  'olive oil',
#  'fresh lemon juice',
#  'light sour cream',
#  'ground black pepper',
#  'pecorino romano cheese',
#  'large egg whites',
#  'large eggs',
#  'salt',
#  'olive oil',
#  'mushrooms',
#  'fava beans',
#  'finely chopped fresh parsley',
#  'fresh tarragon',
#  'salt',
#  'granulated sugar',
#  'eggs',
#  'grated lemon zest',
#  'cake flour',
#  'chopped almonds',
#  'dried oregano',
#  'dried basil',
#  'broccoli',
#  'grated parmesan cheese',
#  'dry bread crumbs',
#  'pepper',
#  'salt',
#  'potatoes',
#  'eggs',
#  'all-purpose flour',
#  'self rising flour',
#  'eggplant',
#  'fresh basil leaves',
#  'cooking spray',
#  'chicken',
#  'pitas',
#  'plum tomatoes',
#  'goat cheese',
#  'ground black pepper',
#  'reduced fat milk',
#  'smoked trout',
#  'large egg whites',
#  'large eggs',
#  'salt',
#  'fresh dill',
#  'parmigiano reggiano cheese',
#  'green onions',
#  'asparagus',
#  'cooking spray',
#  'canola oil',
#  'large egg whites',
#  'oil',
#  'kosher salt',
#  'ground black pepper',
#  'cream of tartar',
#  'olive oil',
#  'fresh parsley',
#  'ricotta salata',
#  'green onions',
#  'unsalted butter',
#  'pecorino cheese',
#  'grana padano',
#  'pasta',
#  'cracked black pepper',
#  'kosher salt',
#  'green bell pepper',
#  'garlic',
#  'shredded mozzarella cheese',
#  'vidalia onion',
#  'marinara sauce',
#  'baby carrots',
#  'pepper',
#  'salt',
#  'smoked gouda',
#  'baby spinach leaves',
#  'shredded sharp cheddar cheese',
#  'small red potato',
#  'Bertolli® Classico Olive Oil',
#  'boneless skinless chicken breast halves',
#  'eggs',
#  'linguine',
#  'chicken broth',
#  'bacon, crisp-cooked and crumbled',
#  'bertolli vineyard premium collect marinara with burgundi wine sauc',
#  'bread crumb fresh',
#  'shredded mozzarella cheese',
#  '(    oz.) tomato sauce',
#  'ground veal',
#  'sliced mushrooms',
#  'italian seasoning mix',
#  'finely chopped onion',
#  'dry bread crumbs',
#  'spaghetti',
#  'beef',
#  'diced tomatoes',
#  'fresh basil leaves',
#  'parmesan cheese',
#  'large eggs',
#  'fat skimmed chicken broth',
#  'solid pack pumpkin',
#  'dry white wine',
#  'corn starch',
#  'ground nutmeg',
#  'white rice',
#  'chicken broth',
#  'grated parmesan cheese',
#  'salt',
#  'ground pepper',
#  'butter',
#  'onions',
#  'fresh rosemary',
#  'fresh thyme leaves',
#  'flat leaf parsley',
#  'olive oil',
#  'baby carrots',
#  'kosher salt',
#  'balsamic vinegar',
#  'onions',
#  'ground black pepper',
#  'small red potato',
#  'pistachios',
#  'salt',
#  'dried cherry',
#  'butter',
#  'large eggs',
#  'vanilla extract',
#  'sugar',
#  'baking powder',
#  'all-purpose flour',
#  'pepper',
#  'garlic',
#  'eggs',
#  'grated parmesan cheese',
#  'fresh parsley',
#  'prosciutto',
#  'salt',
#  'romano cheese',
#  'ricotta cheese',
#  'kosher salt',
#  'butter',
#  'garlic',
#  'dry white wine',
#  'extra-virgin olive oil',
#  'parsley leaves',
#  'lemon',
#  'shrimp',
#  'black pepper',
#  'shallots',
#  'linguine',
#  'water',
#  'fresh lemon juice',
#  'fresh raspberries',
#  'sugar',
#  'dry vermouth',
#  'flour',
#  'salt',
#  'canned low sodium chicken broth',
#  'ground black pepper',
#  'garlic',
#  'pinenuts',
#  'butter',
#  'chicken livers',
#  'olive oil',
#  'raisins',
#  'flat leaf parsley',
#  'seasoned bread crumbs',
#  'grated parmesan cheese',
#  'salt',
#  'fresh parsley',
#  'chicken broth',
#  'minced garlic',
#  'half & half',
#  'shredded mozzarella cheese',
#  'frozen chopped spinach',
#  'pepper',
#  'flour',
#  'penne pasta',
#  'black pepper',
#  'large eggs',
#  'butter',
#  'ground beef',
#  'jack cheese',
#  'vegetables',
#  'dry white wine',
#  'lemon juice',
#  'arborio rice',
#  'olive oil',
#  'unsalted butter',
#  'ricotta',
#  'pepper',
#  'asparagus',
#  'yellow onion',
#  'frozen peas',
#  'reduced sodium chicken broth',
#  'prosciutto',
#  'salt',
#  'chopped fresh mint',
#  'sugar',
#  'linguine',
#  'boneless skinless chicken breast halves',
#  'balsamic vinegar',
#  'oil',
#  'fresh basil',
#  'large garlic cloves',
#  'low salt chicken broth',
#  'olive oil',
#  'purple onion',
#  'eggplant',
#  'low sodium chicken broth',
#  'fresh basil leaves',
#  'pepper',
#  'grated parmesan cheese',
#  'goat cheese',
#  'zucchini',
#  'salt',
#  'polenta',
#  'water',
#  'bell pepper',
#  'olive oil cooking spray',
#  'black pepper',
#  'bacon',
#  'grated parmesan cheese',
#  'flat leaf parsley',
#  'kosher salt',
#  'linguine',
#  'egg yolks',
#  'extra-virgin olive oil',
#  'fresh rosemary',
#  'duck breast halves',
#  'fennel seeds',
#  'garlic cloves',
#  'roma tomatoes',
#  'pizza crust',
#  'goat cheese',
#  'pesto sauce',
#  'garlic',
#  'olive oil',
#  'arugula',
#  'bell pepper',
#  'purple onion',
#  'fresh lemon juice',
#  'tomatoes',
#  'summer squash',
#  'garlic cloves',
#  'flat leaf parsley',
#  'red wine vinegar',
#  'ciabatta',
#  'juice',
#  'capers',
#  'extra-virgin olive oil',
#  'fresh herbs',
#  'grated lemon peel',
#  'dough',
#  'cracked black pepper',
#  'coarse sea salt',
#  'lemon',
#  'olive oil flavored cooking spray',
#  'pinenuts',
#  'rosemary leaves',
#  'prosciutto',
#  'mushrooms',
#  'salt',
#  'grated parmesan cheese',
#  'red pepper flakes',
#  'boneless skinless chicken breast halves',
#  'water',
#  'roma tomatoes',
#  'garlic',
#  'dried oregano',
#  'ground black pepper',
#  'dry white wine',
#  'brie cheese',
#  'cheese ravioli',
#  'evaporated milk',
#  'Italian seasoned breadcrumbs',
#  'eggs',
#  'cheese',
#  'parsley',
#  'smoked gouda',
#  'black pepper',
#  'olive oil',
#  'fat-free cottage cheese',
#  'dried oregano',
#  'dried basil',
#  'grated parmesan cheese',
#  'salt',
#  'water',
#  'part-skim mozzarella cheese',
#  'crushed red pepper',
#  'fresh basil',
#  'cherry tomatoes',
#  'cooking spray',
#  'oven-ready lasagna noodles',
#  'skim milk',
#  'margarine',
#  'garlic',
#  'freshly ground pepper',
#  'grated parmesan cheese',
#  'cream cheese',
#  'fettucine',
#  'all-purpose flour',
#  'fresh parsley',
#  'chopped fresh thyme',
#  'olive oil',
#  'radicchio',
#  'balsamic vinegar',
#  'garbanzo beans',
#  'large garlic cloves',
#  'plum tomatoes',
#  'orzo pasta',
#  'fresh parsley',
#  'grated parmesan cheese',
#  'rubbed sage',
#  'dried rosemary',
#  'olive oil',
#  'canned beef broth',
#  'onions',
#  'kale leaves',
#  'chicken noodle soup',
#  'cannellini beans',
#  'cherry tomatoes',
#  'black pepper',
#  'salt',
#  'balsamic vinegar',
#  'mozzarella cheese',
#  'fresh basil leaves',
#  'white onion',
#  'italian style rolls',
#  'provolone cheese',
#  'genoa salami',
#  'olive oil',
#  'sweet pepper',
#  'oregano',
#  'pepper',
#  'red wine vinegar',
#  'boiled ham',
#  'tomatoes',
#  'capicola',
#  'salt',
#  'iceberg lettuce',
#  'navy beans',
#  'jalapeno chilies',
#  'diced celery',
#  'water',
#  'italian salad dressing mix',
#  'chopped cilantro fresh',
#  'cider vinegar',
#  'diced tomatoes',
#  'red bell pepper',
#  'olive oil',
#  'garlic cloves',
#  'sliced green onions',
#  'barbecue sauce',
#  'yellow onion',
#  'prepared pizza crust',
#  'boneless skinless chicken breasts',
#  'Sargento® Traditional Cut Shredded Mozzarella Cheese',
#  'vegetable oil',
#  'vegetables',
#  'basil',
#  'basil pesto sauce',
#  'aioli',
#  'cooked shrimp',
#  'prosciutto',
#  'mozzarella balls',
#  'sun-dried tomatoes',
#  'salami',
#  'boneless skinless chicken breasts',
#  'milk',
#  'condensed cream of mushroom soup',
#  'fettuccine pasta',
#  'butter',
#  'grated parmesan cheese',
#  'broccoli',
#  'olive oil',
#  'grated parmesan cheese',
#  'frozen spinach',
#  'lasagne',
#  'passata',
#  'eggplant',
#  'mushrooms',
#  'pinenuts',
#  'roasted red peppers',
#  'ricotta',
#  'ground black pepper',
#  'parsley',
#  'fat free cream cheese',
#  'french bread',
#  'non-fat sour cream',
#  'green onions',
#  'reduced fat swiss cheese',
#  'grated parmesan cheese',
#  'garlic',
#  'fat-free mayonnaise',
#  'black pepper',
#  'cannellini beans',
#  'roasted garlic',
#  'seasoning',
#  'kale',
#  'extra-virgin olive oil',
#  'fat free less sodium chicken broth',
#  'diced tomatoes',
#  'Italian bread',
#  'sundried tomato paste',
#  'dried thyme',
#  'salt',
#  'porcini',
#  'fresh thyme',
#  'garlic cloves',
#  'sourdough loaf',
#  'crust',
#  'flat leaf parsley',
#  'duck fat',
#  'fine sea salt',
#  'squabs',
#  'confit',
#  'fresh lemon juice',
#  'aged gouda',
#  'soppressata',
#  'tomato paste',
#  'pepper',
#  'dry white wine',
#  'garlic cloves',
#  'boiling water',
#  'black pepper',
#  'grated parmesan cheese',
#  'salt',
#  'boneless skinless chicken breast halves',
#  'dried porcini mushrooms',
#  'sun-dried tomatoes',
#  'purple onion',
#  'fresh parsley',
#  'chicken broth',
#  'olive oil',
#  'artichokes',
#  'fresh lemon juice',
#  'hot red pepper flakes',
#  'balsamic vinegar',
#  'fresh basil leaves',
#  'pasta',
#  'prosciutto',
#  'garlic cloves',
#  'capers',
#  'finely chopped onion',
#  'juice',
#  'olive oil',
#  'anchovy fillets',
#  'fat free less sodium chicken broth',
#  'dry white wine',
#  'fresh lemon juice',
#  'capers',
#  'olive oil',
#  'butter',
#  'black pepper',
#  'broccoli rabe',
#  'lemon slices',
#  'seasoned bread crumbs',
#  'chicken cutlets',
#  'fresh parsley',
#  'saffron threads',
#  'olive oil',
#  'dry white wine',
#  'grape tomatoes',
#  'parmigiano reggiano cheese',
#  'salt',
#  'fresh rosemary',
#  'unsalted butter',
#  'orzo',
#  'black pepper',
#  'veal chops',
#  'garlic cloves',
#  'grated parmesan cheese',
#  'extra-virgin olive oil',
#  'pepper',
#  'red wine vinegar',
#  'fresh oregano',
#  'oil cured olives',
#  'green onions',
#  'salt',
#  'garbanzo beans',
#  'pasta rotel',
#  'fresh parsley',
#  'parmesan cheese',
#  'garlic',
#  'pasta water',
#  'chicken broth',
#  'boneless skinless chicken breasts',
#  'salt',
#  'onions',
#  'unsalted butter',
#  'cooking wine',
#  'fresh parsley',
#  'pepper',
#  'heavy cream',
#  'sliced mushrooms',
#  'parmigiano reggiano cheese',
#  'crusty bread',
#  'parsley',
#  'eggs',
#  'marinara sauce',
#  'mozzarella cheese',
#  'fresh tomatoes',
#  'diced tomatoes',
#  'onions',
#  'olive oil',
#  'garlic',
#  'tomato sauce',
#  'uncooked rigatoni',
#  'fresh basil',
#  'grating cheese',
#  'salt',
#  'arborio rice',
#  'ground black pepper',
#  'onions',
#  'sun-dried tomatoes',
#  'vegetable stock',
#  'dried thyme',
#  'zucchini',
#  'fresh basil leaves',
#  'freshly grated parmesan',
#  'butter',
#  'arborio rice',
#  'olive oil',
#  'brie cheese',
#  'reduced sodium chicken broth',
#  'dry white wine',
#  'cauliflower',
#  'water',
#  'florets',
#  'sliced almonds',
#  'unsalted butter',
#  'thyme sprigs',
#  'salt',
#  'egg whites',
#  'margarine',
#  'baking powder',
#  'greek yogurt',
#  'milk',
#  'all-purpose flour',
#  'penne',
#  'garlic',
#  'eggplant',
#  'lemon juice',
#  'olive oil',
#  'salt',
#  'ground black pepper',
#  'fresh parsley',
#  'cold water',
#  'dry white wine',
#  'fish fillets',
#  'chopped onion',
#  'olive oil',
#  'fresh parsley',
#  'tomatoes',
#  'large garlic cloves',
#  'large eggs',
#  'whipping cream',
#  'ground nutmeg',
#  'chopped fresh chives',
#  'all-purpose flour',
#  'grated parmesan cheese',
#  'salt',
#  'ground black pepper',
#  'russet potatoes',
#  'crumbled gorgonzola',
#  'fontina cheese',
#  'russet potatoes',
#  'eggs',
#  'all-purpose flour',
#  'ground nutmeg',
#  'spinach leaves',
#  'butter',
#  'tomato paste',
#  'orange',
#  'extra-virgin olive oil',
#  'lamb shanks',
#  'bay leaves',
#  'low salt chicken broth',
#  'clove',
#  'dried porcini mushrooms',
#  'dry red wine',
#  'polenta',
#  'rosemary sprigs',
#  'finely chopped onion',
#  'hot water',
#  'olive oil',
#  'flat leaf parsley',
#  'grated parmesan cheese',
#  'garlic cloves',
#  'chopped tomatoes',
#  'spaghetti',
#  ...]

# %%
def get_ngrams(i_list):
    all_grams = []
    
    for i in i_list:
        l = clean_text(i)
        grams = list(nltk.everygrams(l, max_len=len(l)))
        grams.sort(key=len, reverse=True)        
        grams = [' '.join(g) for g in grams]
        all_grams.append(grams)
    
    return all_grams

# %%
stop_words = set(stopwords.words('english'))
get_ngrams(temp)
# Out:
# [['sugar'],
#  ['pistachio nuts', 'pistachio', 'nuts'],
#  ['white almond bark',
#   'white almond',
#   'almond bark',
#   'white',
#   'almond',
#   'bark'],
#  ['flour'],
#  ['vanilla extract', 'vanilla', 'extract'],
#  ['olive oil', 'olive', 'oil'],
#  ['almond extract', 'almond', 'extract'],
#  ['eggs'],
#  ['baking powder', 'baking', 'powder'],
#  ['dried cranberries', 'dried', 'cranberries'],
#  ['chopped tomatoes', 'chopped', 'tomatoes'],
#  ['fresh basil', 'fresh', 'basil'],
#  ['garlic'],
#  ['extra virgin olive oil',
#   'extra virgin olive',
#   'virgin olive oil',
#   'extra virgin',
#   'virgin olive',
#   'olive oil',
#   'extra',
#   'virgin',
#   'olive',
#   'oil'],
#  ['kosher salt', 'kosher', 'salt'],
#  ['flat leaf parsley', 'flat leaf', 'leaf parsley', 'flat', 'leaf', 'parsley'],
#  ['pimentos'],
#  ['sweet pepper', 'sweet', 'pepper'],
#  ['dried oregano', 'dried', 'oregano'],
#  ['olive oil', 'olive', 'oil'],
#  ['garlic'],
#  ['sharp cheddar cheese',
#   'sharp cheddar',
#   'cheddar cheese',
#   'sharp',
#   'cheddar',
#   'cheese'],
#  ['pepper'],
#  ['swiss cheese', 'swiss', 'cheese'],
#  ['provolone cheese', 'provolone', 'cheese'],
#  ['canola oil', 'canola', 'oil'],
#  ['mushrooms'],
#  ['black olives', 'black', 'olives'],
#  ['sausages'],
#  ['italian parsley leaves',
#   'italian parsley',
#   'parsley leaves',
#   'italian',
#   'parsley',
#   'leaves'],
#  ['walnuts'],
#  ['hot red pepper flakes',
#   'hot red pepper',
#   'red pepper flakes',
#   'hot red',
#   'red pepper',
#   'pepper flakes',
#   'hot',
#   'red',
#   'pepper',
#   'flakes'],
#  ['extra virgin olive oil',
#   'extra virgin olive',
#   'virgin olive oil',
#   'extra virgin',
#   'virgin olive',
#   'olive oil',
#   'extra',
#   'virgin',
#   'olive',
#   'oil'],
#  ['fresh lemon juice',
#   'fresh lemon',
#   'lemon juice',
#   'fresh',
#   'lemon',
#   'juice'],
#  ['trout fillet', 'trout', 'fillet'],
#  ['garlic cloves', 'garlic', 'cloves'],
#  ['chipotle chile', 'chipotle', 'chile'],
#  ['fine sea salt', 'fine sea', 'sea salt', 'fine', 'sea', 'salt'],
#  ['flat leaf parsley', 'flat leaf', 'leaf parsley', 'flat', 'leaf', 'parsley'],
#  ['fresh parmesan cheese',
#   'fresh parmesan',
#   'parmesan cheese',
#   'fresh',
#   'parmesan',
#   'cheese'],
#  ['butter'],
#  ['purpose flour', 'purpose', 'flour'],
#  ['fat free less sodium chicken broth',
#   'fat free less sodium chicken',
#   'free less sodium chicken broth',
#   'fat free less sodium',
#   'free less sodium chicken',
#   'less sodium chicken broth',
#   'fat free less',
#   'free less sodium',
#   'less sodium chicken',
#   'sodium chicken broth',
#   'fat free',
#   'free less',
#   'less sodium',
#   'sodium chicken',
#   'chicken broth',
#   'fat',
#   'free',
#   'less',
#   'sodium',
#   'chicken',
#   'broth'],
#  ['chopped fresh chives',
#   'chopped fresh',
#   'fresh chives',
#   'chopped',
#   'fresh',
#   'chives'],
#  ['gruyere cheese', 'gruyere', 'cheese'],
#  ['ground black pepper',
#   'ground black',
#   'black pepper',
#   'ground',
#   'black',
#   'pepper'],
#  ['bacon slices', 'bacon', 'slices'],
#  ['gnocchi'],
#  ['fat free milk', 'fat free', 'free milk', 'fat', 'free', 'milk'],
#  ['cooking spray', 'cooking', 'spray'],
#  ['salt'],
#  ['italian seasoning', 'italian', 'seasoning'],
#  ['broiler fryer chicken',
#   'broiler fryer',
#   'fryer chicken',
#   'broiler',
#   'fryer',
#   'chicken'],
#  ['mayonaise'],
#  ['zesty italian dressing',
#   'zesty italian',
#   'italian dressing',
#   'zesty',
#   'italian',
#   'dressing'],
#  ['marinara sauce', 'marinara', 'sauce'],
#  ['flat leaf parsley', 'flat leaf', 'leaf parsley', 'flat', 'leaf', 'parsley'],
#  ['olive oil', 'olive', 'oil'],
#  ['linguine'],
#  ['capers'],
#  ['crushed red pepper flakes',
#   'crushed red pepper',
#   'red pepper flakes',
#   'crushed red',
#   'red pepper',
#   'pepper flakes',
#   'crushed',
#   'red',
#   'pepper',
#   'flakes'],
#  ['olives'],
#  ['lemon zest', 'lemon', 'zest'],
#  ['garlic'],
#  ['ground black pepper',
#   'ground black',
#   'black pepper',
#   'ground',
#   'black',
#   'pepper'],
#  ['butter'],
#  ['sliced mushrooms', 'sliced', 'mushrooms'],
#  ['sherry'],
#  ['salt'],
#  ['grated parmesan cheese',
#   'grated parmesan',
#   'parmesan cheese',
#   'grated',
#   'parmesan',
#   'cheese'],
#  ['heavy cream', 'heavy', 'cream'],
#  ['spaghetti'],
#  ['chicken broth', 'chicken', 'broth'],
#  ['cooked chicken', 'cooked', 'chicken'],
#  ['purpose flour', 'purpose', 'flour'],
#  ['yellow corn meal', 'yellow corn', 'corn meal', 'yellow', 'corn', 'meal'],
#  ['boiling water', 'boiling', 'water'],
#  ['butter'],
#  ['fresh parmesan cheese',
#   'fresh parmesan',
#   'parmesan cheese',
#   'fresh',
#   'parmesan',
#   'cheese'],
#  ['sea salt', 'sea', 'salt'],
#  ['olive oil', 'olive', 'oil'],
#  ['onions'],
#  ['crushed garlic', 'crushed', 'garlic'],
#  ['dried oregano', 'dried', 'oregano'],
#  ['green onions', 'green', 'onions'],
#  ['white sugar', 'white', 'sugar'],
#  ['dried basil', 'dried', 'basil'],
#  ['diced tomatoes', 'diced', 'tomatoes'],
#  ['olive oil', 'olive', 'oil'],
#  ['bread slices', 'bread', 'slices'],
#  ['great northern beans',
#   'great northern',
#   'northern beans',
#   'great',
#   'northern',
#   'beans'],
#  ['garlic cloves', 'garlic', 'cloves'],
#  ['pepper'],
#  ['shrimp'],
#  ['sage leaves', 'sage', 'leaves'],
#  ['salt'],
#  ['oscar mayer deli fresh smoked ham',
#   'oscar mayer deli fresh smoked',
#   'mayer deli fresh smoked ham',
#   'oscar mayer deli fresh',
#   'mayer deli fresh smoked',
#   'deli fresh smoked ham',
#   'oscar mayer deli',
#   'mayer deli fresh',
#   'deli fresh smoked',
#   'fresh smoked ham',
#   'oscar mayer',
#   'mayer deli',
#   'deli fresh',
#   'fresh smoked',
#   'smoked ham',
#   'oscar',
#   'mayer',
#   'deli',
#   'fresh',
#   'smoked',
#   'ham'],
#  ['hoagie rolls', 'hoagie', 'rolls'],
#  ['salami'],
#  ['giardiniera'],
#  ['mozzarella cheese', 'mozzarella', 'cheese'],
#  ['pepperoni'],
#  ['butter'],
#  ['italian seasoning', 'italian', 'seasoning'],
#  ['fresh basil', 'fresh', 'basil'],
#  ['bay leaves', 'bay', 'leaves'],
#  ['crushed red pepper',
#   'crushed red',
#   'red pepper',
#   'crushed',
#   'red',
#   'pepper'],
#  ['mussels'],
#  ['olive oil', 'olive', 'oil'],
#  ['basil'],
#  ['garlic cloves', 'garlic', 'cloves'],
#  ['black pepper', 'black', 'pepper'],
#  ['dry white wine', 'dry white', 'white wine', 'dry', 'white', 'wine'],
#  ['salt'],
#  ['tomatoes'],
#  ['finely chopped onion',
#   'finely chopped',
#   'chopped onion',
#   'finely',
#   'chopped',
#   'onion'],
#  ['linguine'],
#  ['flat leaf parsley', 'flat leaf', 'leaf parsley', 'flat', 'leaf', 'parsley'],
#  ['lemon'],
#  ['pesto'],
#  ['salmon fillets', 'salmon', 'fillets'],
#  ['white wine', 'white', 'wine'],
#  ['pizza crust', 'pizza', 'crust'],
#  ['plum tomatoes', 'plum', 'tomatoes'],
#  ['pesto'],
#  ['part skim mozzarella cheese',
#   'part skim mozzarella',
#   'skim mozzarella cheese',
#   'part skim',
#   'skim mozzarella',
#   'mozzarella cheese',
#   'part',
#   'skim',
#   'mozzarella',
#   'cheese'],
#  ['crushed tomatoes', 'crushed', 'tomatoes'],
#  ['garlic'],
#  ['fresh rosemary', 'fresh', 'rosemary'],
#  ['ground black pepper',
#   'ground black',
#   'black pepper',
#   'ground',
#   'black',
#   'pepper'],
#  ['onions'],
#  ['olive oil', 'olive', 'oil'],
#  ['boneless pork loin',
#   'boneless pork',
#   'pork loin',
#   'boneless',
#   'pork',
#   'loin'],
#  ['kosher salt', 'kosher', 'salt'],
#  ['pappardelle'],
#  ['tomatoes'],
#  ['red pepper', 'red', 'pepper'],
#  ['olive oil', 'olive', 'oil'],
#  ['italian bread', 'italian', 'bread'],
#  ['balsamic vinegar', 'balsamic', 'vinegar'],
#  ['onions'],
#  ['fresh basil', 'fresh', 'basil'],
#  ['garlic'],
#  ['sausage casings', 'sausage', 'casings'],
#  ['ground black pepper',
#   'ground black',
#   'black pepper',
#   'ground',
#   'black',
#   'pepper'],
#  ['garlic'],
#  ['honey'],
#  ['grated parmesan cheese',
#   'grated parmesan',
#   'parmesan cheese',
#   'grated',
#   'parmesan',
#   'cheese'],
#  ['shredded mozzarella cheese',
#   'shredded mozzarella',
#   'mozzarella cheese',
#   'shredded',
#   'mozzarella',
#   'cheese'],
#  ['kosher salt', 'kosher', 'salt'],
#  ['roasted red peppers',
#   'roasted red',
#   'red peppers',
#   'roasted',
#   'red',
#   'peppers'],
#  ['penne pasta', 'penne', 'pasta'],
#  ['olive oil', 'olive', 'oil'],
#  ['crushed red pepper flakes',
#   'crushed red pepper',
#   'red pepper flakes',
#   'crushed red',
#   'red pepper',
#   'pepper flakes',
#   'crushed',
#   'red',
#   'pepper',
#   'flakes'],
#  ['spinach'],
#  ['asiago'],
#  ['whole wheat pasta',
#   'whole wheat',
#   'wheat pasta',
#   'whole',
#   'wheat',
#   'pasta'],
#  ['olive oil', 'olive', 'oil'],
#  ['sweet onion', 'sweet', 'onion'],
#  ['garlic'],
#  ['grape tomatoes', 'grape', 'tomatoes'],
#  ['mushrooms'],
#  ['chestnuts'],
#  ['granulated sugar', 'granulated', 'sugar'],
#  ['whole milk ricotta cheese',
#   'whole milk ricotta',
#   'milk ricotta cheese',
#   'whole milk',
#   'milk ricotta',
#   'ricotta cheese',
#   'whole',
#   'milk',
#   'ricotta',
#   'cheese'],
#  ['coffee ice cream', 'coffee ice', 'ice cream', 'coffee', 'ice', 'cream'],
#  ['large eggs', 'large', 'eggs'],
#  ['mascarpone'],
#  ['rum'],
#  ['powdered sugar', 'powdered', 'sugar'],
#  ['semisweet chocolate', 'semisweet', 'chocolate'],
#  ['chestnut flour', 'chestnut', 'flour'],
#  ['salt'],
#  ['starchy potatoes', 'starchy', 'potatoes'],
#  ['grated nutmeg', 'grated', 'nutmeg'],
#  ['flour'],
#  ['olive oil', 'olive', 'oil'],
#  ['olives'],
#  ['salt'],
#  ['blood orange', 'blood', 'orange'],
#  ['freshly ground pepper',
#   'freshly ground',
#   'ground pepper',
#   'freshly',
#   'ground',
#   'pepper'],
#  ['fennel bulb', 'fennel', 'bulb'],
#  ['balsamic vinegar', 'balsamic', 'vinegar'],
#  ['low salt chicken broth',
#   'low salt chicken',
#   'salt chicken broth',
#   'low salt',
#   'salt chicken',
#   'chicken broth',
#   'low',
#   'salt',
#   'chicken',
#   'broth'],
#  ['dijon mustard', 'dijon', 'mustard'],
#  ['corn starch', 'corn', 'starch'],
#  ['dried basil', 'dried', 'basil'],
#  ['garlic cloves', 'garlic', 'cloves'],
#  ['white wine vinegar',
#   'white wine',
#   'wine vinegar',
#   'white',
#   'wine',
#   'vinegar'],
#  ['tomato sauce', 'tomato', 'sauce'],
#  ['shredded carrots', 'shredded', 'carrots'],
#  ['spinach'],
#  ['part skim mozzarella cheese',
#   'part skim mozzarella',
#   'skim mozzarella cheese',
#   'part skim',
#   'skim mozzarella',
#   'mozzarella cheese',
#   'part',
#   'skim',
#   'mozzarella',
#   'cheese'],
#  ['italian seasoning', 'italian', 'seasoning'],
#  ['english muffins split toasted',
#   'english muffins split',
#   'muffins split toasted',
#   'english muffins',
#   'muffins split',
#   'split toasted',
#   'english',
#   'muffins',
#   'split',
#   'toasted'],
#  ['chopped onion', 'chopped', 'onion'],
#  ['vegetable oil cooking spray',
#   'vegetable oil cooking',
#   'oil cooking spray',
#   'vegetable oil',
#   'oil cooking',
#   'cooking spray',
#   'vegetable',
#   'oil',
#   'cooking',
#   'spray'],
#  ['chopped green bell pepper',
#   'chopped green bell',
#   'green bell pepper',
#   'chopped green',
#   'green bell',
#   'bell pepper',
#   'chopped',
#   'green',
#   'bell',
#   'pepper'],
#  ['cheddar cheese', 'cheddar', 'cheese'],
#  ['lasagna noodles', 'lasagna', 'noodles'],
#  ['pepper'],
#  ['ranch dressing', 'ranch', 'dressing'],
#  ['mozzarella cheese', 'mozzarella', 'cheese'],
#  ['cooked chicken', 'cooked', 'chicken'],
#  ['evaporated milk', 'evaporated', 'milk'],
#  ['olive oil', 'olive', 'oil'],
#  ['freshly ground pepper',
#   'freshly ground',
#   'ground pepper',
#   'freshly',
#   'ground',
#   'pepper'],
#  ['fresh rosemary', 'fresh', 'rosemary'],
#  ['salt'],
#  ['fresh parsley', 'fresh', 'parsley'],
#  ['fresh basil', 'fresh', 'basil'],
#  ['fresh oregano', 'fresh', 'oregano'],
#  ['crushed red pepper',
#   'crushed red',
#   'red pepper',
#   'crushed',
#   'red',
#   'pepper'],
#  ['garlic cloves', 'garlic', 'cloves'],
#  ['cold water', 'cold', 'water'],
#  ['sugar'],
#  ['butter'],
#  ['chocolate morsels', 'chocolate', 'morsels'],
#  ['cream sweeten whip',
#   'cream sweeten',
#   'sweeten whip',
#   'cream',
#   'sweeten',
#   'whip'],
#  ['instant espresso granules',
#   'instant espresso',
#   'espresso granules',
#   'instant',
#   'espresso',
#   'granules'],
#  ['whipping cream', 'whipping', 'cream'],
#  ['boiling water', 'boiling', 'water'],
#  ['kahl'],
#  ['large eggs', 'large', 'eggs'],
#  ['chocolate covered coffee beans',
#   'chocolate covered coffee',
#   'covered coffee beans',
#   'chocolate covered',
#   'covered coffee',
#   'coffee beans',
#   'chocolate',
#   'covered',
#   'coffee',
#   'beans'],
#  ['unflavored gelatin', 'unflavored', 'gelatin'],
#  ['mascarpone'],
#  ['pound cake', 'pound', 'cake'],
#  ['pinenuts'],
#  ['zucchini'],
#  ['baby carrots', 'baby', 'carrots'],
#  ['fresh basil leaves',
#   'fresh basil',
#   'basil leaves',
#   'fresh',
#   'basil',
#   'leaves'],
#  ['olive oil', 'olive', 'oil'],
#  ['dry white wine', 'dry white', 'white wine', 'dry', 'white', 'wine'],
#  ['asparagus spears', 'asparagus', 'spears'],
#  ['white onion', 'white', 'onion'],
#  ['grated parmesan cheese',
#   'grated parmesan',
#   'parmesan cheese',
#   'grated',
#   'parmesan',
#   'cheese'],
#  ['carrots'],
#  ['frozen peas', 'frozen', 'peas'],
#  ['arborio rice', 'arborio', 'rice'],
#  ['yellow crookneck squash',
#   'yellow crookneck',
#   'crookneck squash',
#   'yellow',
#   'crookneck',
#   'squash'],
#  ['butter'],
#  ['low salt chicken broth',
#   'low salt chicken',
#   'salt chicken broth',
#   'low salt',
#   'salt chicken',
#   'chicken broth',
#   'low',
#   'salt',
#   'chicken',
#   'broth'],
#  ['fresh leav spinach',
#   'fresh leav',
#   'leav spinach',
#   'fresh',
#   'leav',
#   'spinach'],
#  ['cheese tortellini', 'cheese', 'tortellini'],
#  ['fresh basil', 'fresh', 'basil'],
#  ['cherry tomatoes', 'cherry', 'tomatoes'],
#  ['fresh lemon juice',
#   'fresh lemon',
#   'lemon juice',
#   'fresh',
#   'lemon',
#   'juice'],
#  ['capers'],
#  ['fresh parmesan cheese',
#   'fresh parmesan',
#   'parmesan cheese',
#   'fresh',
#   'parmesan',
#   'cheese'],
#  ['navy beans', 'navy', 'beans'],
#  ['pepper'],
#  ['extra virgin olive oil',
#   'extra virgin olive',
#   'virgin olive oil',
#   'extra virgin',
#   'virgin olive',
#   'olive oil',
#   'extra',
#   'virgin',
#   'olive',
#   'oil'],
#  ['pecorino romano cheese',
#   'pecorino romano',
#   'romano cheese',
#   'pecorino',
#   'romano',
#   'cheese'],
#  ['fresh fava bean', 'fresh fava', 'fava bean', 'fresh', 'fava', 'bean'],
#  ['finely chopped onion',
#   'finely chopped',
#   'chopped onion',
#   'finely',
#   'chopped',
#   'onion'],
#  ['extra virgin olive oil',
#   'extra virgin olive',
#   'virgin olive oil',
#   'extra virgin',
#   'virgin olive',
#   'olive oil',
#   'extra',
#   'virgin',
#   'olive',
#   'oil'],
#  ['plum tomatoes', 'plum', 'tomatoes'],
#  ['italian sausage', 'italian', 'sausage'],
#  ['large garlic cloves',
#   'large garlic',
#   'garlic cloves',
#   'large',
#   'garlic',
#   'cloves'],
#  ['pasta sheets', 'pasta', 'sheets'],
#  ['dry white wine', 'dry white', 'white wine', 'dry', 'white', 'wine'],
#  ['crushed red pepper',
#   'crushed red',
#   'red pepper',
#   'crushed',
#   'red',
#   'pepper'],
#  ['shredded mozzarella cheese',
#   'shredded mozzarella',
#   'mozzarella cheese',
#   'shredded',
#   'mozzarella',
#   'cheese'],
#  ['marinara sauce', 'marinara', 'sauce'],
#  ['fresh basil leaves',
#   'fresh basil',
#   'basil leaves',
#   'fresh',
#   'basil',
#   'leaves'],
#  ['penne pasta', 'penne', 'pasta'],
#  ['water'],
#  ['extra virgin olive oil',
#   'extra virgin olive',
#   'virgin olive oil',
#   'extra virgin',
#   'virgin olive',
#   'olive oil',
#   'extra',
#   'virgin',
#   'olive',
#   'oil'],
#  ['carrots'],
#  ['hot red pepper flakes',
#   'hot red pepper',
#   'red pepper flakes',
#   'hot red',
#   'red pepper',
#   'pepper flakes',
#   'hot',
#   'red',
#   'pepper',
#   'flakes'],
#  ['turkish bay leaves',
#   'turkish bay',
#   'bay leaves',
#   'turkish',
#   'bay',
#   'leaves'],
#  ['dried chickpeas', 'dried', 'chickpeas'],
#  ['onions'],
#  ['celery ribs', 'celery', 'ribs'],
#  ['semolina'],
#  ['fine sea salt', 'fine sea', 'sea salt', 'fine', 'sea', 'salt'],
#  ['flat leaf parsley', 'flat leaf', 'leaf parsley', 'flat', 'leaf', 'parsley'],
#  ['warm water', 'warm', 'water'],
#  ['vine ripened tomatoes',
#   'vine ripened',
#   'ripened tomatoes',
#   'vine',
#   'ripened',
#   'tomatoes'],
#  ['garlic cloves', 'garlic', 'cloves'],
#  ['sugar'],
#  ['mascarpone'],
#  ['bittersweet chocolate', 'bittersweet', 'chocolate'],
#  ['fat free yogurt', 'fat free', 'free yogurt', 'fat', 'free', 'yogurt'],
#  ['vanilla extract', 'vanilla', 'extract'],
#  ['skim milk', 'skim', 'milk'],
#  ['angel food cake', 'angel food', 'food cake', 'angel', 'food', 'cake'],
#  ['unsweetened cocoa powder',
#   'unsweetened cocoa',
#   'cocoa powder',
#   'unsweetened',
#   'cocoa',
#   'powder'],
#  ['kahl'],
#  ['water'],
#  ['instant espresso', 'instant', 'espresso'],
#  ['diced tomatoes', 'diced', 'tomatoes'],
#  ['sugar'],
#  ['garlic salt', 'garlic', 'salt'],
#  ['tomato paste', 'tomato', 'paste'],
#  ['crushed red pepper',
#   'crushed red',
#   'red pepper',
#   'crushed',
#   'red',
#   'pepper'],
#  ['dried basil', 'dried', 'basil'],
#  ['dried oregano', 'dried', 'oregano'],
#  ['mushrooms'],
#  ['purpose flour', 'purpose', 'flour'],
#  ['fresh rosemary', 'fresh', 'rosemary'],
#  ['veal cutlets', 'veal', 'cutlets'],
#  ['plum tomatoes', 'plum', 'tomatoes'],
#  ['dry white wine', 'dry white', 'white wine', 'dry', 'white', 'wine'],
#  ['low salt chicken broth',
#   'low salt chicken',
#   'salt chicken broth',
#   'low salt',
#   'salt chicken',
#   'chicken broth',
#   'low',
#   'salt',
#   'chicken',
#   'broth'],
#  ['olive oil', 'olive', 'oil'],
#  ['large garlic cloves',
#   'large garlic',
#   'garlic cloves',
#   'large',
#   'garlic',
#   'cloves'],
#  ['hot red pepper flakes',
#   'hot red pepper',
#   'red pepper flakes',
#   'hot red',
#   'red pepper',
#   'pepper flakes',
#   'hot',
#   'red',
#   'pepper',
#   'flakes'],
#  ['broccoli rabe', 'broccoli', 'rabe'],
#  ['whole milk', 'whole', 'milk'],
#  ['garlic cloves', 'garlic', 'cloves'],
#  ['black pepper', 'black', 'pepper'],
#  ['parmigiano reggiano cheese',
#   'parmigiano reggiano',
#   'reggiano cheese',
#   'parmigiano',
#   'reggiano',
#   'cheese'],
#  ['purpose flour', 'purpose', 'flour'],
#  ['sausage casings', 'sausage', 'casings'],
#  ['olive oil', 'olive', 'oil'],
#  ['large eggs', 'large', 'eggs'],
#  ['dry bread crumbs', 'dry bread', 'bread crumbs', 'dry', 'bread', 'crumbs'],
#  ['fontina'],
#  ['unsalted butter', 'unsalted', 'butter'],
#  ['salt'],
#  ['pasta sauce', 'pasta', 'sauce'],
#  ['fresh parmesan cheese',
#   'fresh parmesan',
#   'parmesan cheese',
#   'fresh',
#   'parmesan',
#   'cheese'],
#  ['olive oil flavored cooking spray',
#   'olive oil flavored cooking',
#   'oil flavored cooking spray',
#   'olive oil flavored',
#   'oil flavored cooking',
#   'flavored cooking spray',
#   'olive oil',
#   'oil flavored',
#   'flavored cooking',
#   'cooking spray',
#   'olive',
#   'oil',
#   'flavored',
#   'cooking',
#   'spray'],
#  ['frozen chopped spinach',
#   'frozen chopped',
#   'chopped spinach',
#   'frozen',
#   'chopped',
#   'spinach'],
#  ['large egg whites', 'large egg', 'egg whites', 'large', 'egg', 'whites'],
#  ['part skim ricotta cheese',
#   'part skim ricotta',
#   'skim ricotta cheese',
#   'part skim',
#   'skim ricotta',
#   'ricotta cheese',
#   'part',
#   'skim',
#   'ricotta',
#   'cheese'],
#  ['pepper'],
#  ['large eggs', 'large', 'eggs'],
#  ['italian seasoning', 'italian', 'seasoning'],
#  ['manicotti shells', 'manicotti', 'shells'],
#  ['part skim mozzarella cheese',
#   'part skim mozzarella',
#   'skim mozzarella cheese',
#   'part skim',
#   'skim mozzarella',
#   'mozzarella cheese',
#   'part',
#   'skim',
#   'mozzarella',
#   'cheese'],
#  ['salt'],
#  ['vegetable oil cooking spray',
#   'vegetable oil cooking',
#   'oil cooking spray',
#   'vegetable oil',
#   'oil cooking',
#   'cooking spray',
#   'vegetable',
#   'oil',
#   'cooking',
#   'spray'],
#  ['dry white wine', 'dry white', 'white wine', 'dry', 'white', 'wine'],
#  ['sliced mushrooms', 'sliced', 'mushrooms'],
#  ['fettucine'],
#  ['olive oil', 'olive', 'oil'],
#  ['fresh oregano', 'fresh', 'oregano'],
#  ['onions'],
#  ['fresh basil', 'fresh', 'basil'],
#  ['parmesan cheese', 'parmesan', 'cheese'],
#  ['corn starch', 'corn', 'starch'],
#  ['large shrimp', 'large', 'shrimp'],
#  ['tomatoes'],
#  ['chicken bouillon', 'chicken', 'bouillon'],
#  ['garlic'],
#  ['flat leaf parsley', 'flat leaf', 'leaf parsley', 'flat', 'leaf', 'parsley'],
#  ['cream tartar', 'cream', 'tartar'],
#  ['pistachio nuts', 'pistachio', 'nuts'],
#  ['salt'],
#  ['orange liqueur', 'orange', 'liqueur'],
#  ['eggs'],
#  ['vanilla extract', 'vanilla', 'extract'],
#  ['heavy whipping cream',
#   'heavy whipping',
#   'whipping cream',
#   'heavy',
#   'whipping',
#   'cream'],
#  ['semi sweet chocolate morsels',
#   'semi sweet chocolate',
#   'sweet chocolate morsels',
#   'semi sweet',
#   'sweet chocolate',
#   'chocolate morsels',
#   'semi',
#   'sweet',
#   'chocolate',
#   'morsels'],
#  ['water'],
#  ['cake flour', 'cake', 'flour'],
#  ['confectioners sugar', 'confectioners', 'sugar'],
#  ['ground cinnamon', 'ground', 'cinnamon'],
#  ['ricotta cheese', 'ricotta', 'cheese'],
#  ['cream cheese', 'cream', 'cheese'],
#  ['white sugar', 'white', 'sugar'],
#  ['dried porcini mushrooms',
#   'dried porcini',
#   'porcini mushrooms',
#   'dried',
#   'porcini',
#   'mushrooms'],
#  ['chopped fresh thyme',
#   'chopped fresh',
#   'fresh thyme',
#   'chopped',
#   'fresh',
#   'thyme'],
#  ['beef rib short', 'beef rib', 'rib short', 'beef', 'rib', 'short'],
#  ['tomato paste', 'tomato', 'paste'],
#  ['kosher salt', 'kosher', 'salt'],
#  ['dry red wine', 'dry red', 'red wine', 'dry', 'red', 'wine'],
#  ['hot water', 'hot', 'water'],
#  ['black pepper', 'black', 'pepper'],
#  ['fat free less sodium beef broth',
#   'fat free less sodium beef',
#   'free less sodium beef broth',
#   'fat free less sodium',
#   'free less sodium beef',
#   'less sodium beef broth',
#   'fat free less',
#   'free less sodium',
#   'less sodium beef',
#   'sodium beef broth',
#   'fat free',
#   'free less',
#   'less sodium',
#   'sodium beef',
#   'beef broth',
#   'fat',
#   'free',
#   'less',
#   'sodium',
#   'beef',
#   'broth'],
#  ['garlic cloves', 'garlic', 'cloves'],
#  ['cremini mushrooms', 'cremini', 'mushrooms'],
#  ['olive oil', 'olive', 'oil'],
#  ['purpose flour', 'purpose', 'flour'],
#  ['onions'],
#  ['pitted kalamata olives',
#   'pitted kalamata',
#   'kalamata olives',
#   'pitted',
#   'kalamata',
#   'olives'],
#  ['grated parmesan cheese',
#   'grated parmesan',
#   'parmesan cheese',
#   'grated',
#   'parmesan',
#   'cheese'],
#  ['penne pasta', 'penne', 'pasta'],
#  ['cauliflower'],
#  ['olive oil', 'olive', 'oil'],
#  ['crushed red pepper',
#   'crushed red',
#   'red pepper',
#   'crushed',
#   'red',
#   'pepper'],
#  ['pepper'],
#  ['garlic'],
#  ['fresh parsley', 'fresh', 'parsley'],
#  ['capers'],
#  ['whole peeled tomatoes',
#   'whole peeled',
#   'peeled tomatoes',
#   'whole',
#   'peeled',
#   'tomatoes'],
#  ['salt'],
#  ['swiss chard', 'swiss', 'chard'],
#  ['diced tomatoes', 'diced', 'tomatoes'],
#  ['chopped onion', 'chopped', 'onion'],
#  ['pepper'],
#  ['banana squash', 'banana', 'squash'],
#  ['garlic'],
#  ['italian seasoning', 'italian', 'seasoning'],
#  ['grated parmesan cheese',
#   'grated parmesan',
#   'parmesan cheese',
#   'grated',
#   'parmesan',
#   'cheese'],
#  ['vegetable broth', 'vegetable', 'broth'],
#  ['bay leaf', 'bay', 'leaf'],
#  ['olive oil', 'olive', 'oil'],
#  ['cannellini beans', 'cannellini', 'beans'],
#  ['salt'],
#  ['ground black pepper',
#   'ground black',
#   'black pepper',
#   'ground',
#   'black',
#   'pepper'],
#  ['fresh parsley', 'fresh', 'parsley'],
#  ['fat free less sodium chicken broth',
#   'fat free less sodium chicken',
#   'free less sodium chicken broth',
#   'fat free less sodium',
#   'free less sodium chicken',
#   'less sodium chicken broth',
#   'fat free less',
#   'free less sodium',
#   'less sodium chicken',
#   'sodium chicken broth',
#   'fat free',
#   'free less',
#   'less sodium',
#   'sodium chicken',
#   'chicken broth',
#   'fat',
#   'free',
#   'less',
#   'sodium',
#   'chicken',
#   'broth'],
#  ['salt'],
#  ['capers'],
#  ['balsamic vinegar', 'balsamic', 'vinegar'],
#  ['boneless skinless chicken breast halves',
#   'boneless skinless chicken breast',
#   'skinless chicken breast halves',
#   'boneless skinless chicken',
#   'skinless chicken breast',
#   'chicken breast halves',
#   'boneless skinless',
#   'skinless chicken',
#   'chicken breast',
#   'breast halves',
#   'boneless',
#   'skinless',
#   'chicken',
#   'breast',
#   'halves'],
#  ['olive oil', 'olive', 'oil'],
#  ['fresh lemon juice',
#   'fresh lemon',
#   'lemon juice',
#   'fresh',
#   'lemon',
#   'juice'],
#  ['light sour cream', 'light sour', 'sour cream', 'light', 'sour', 'cream'],
#  ['ground black pepper',
#   'ground black',
#   'black pepper',
#   'ground',
#   'black',
#   'pepper'],
#  ['pecorino romano cheese',
#   'pecorino romano',
#   'romano cheese',
#   'pecorino',
#   'romano',
#   'cheese'],
#  ['large egg whites', 'large egg', 'egg whites', 'large', 'egg', 'whites'],
#  ['large eggs', 'large', 'eggs'],
#  ['salt'],
#  ['olive oil', 'olive', 'oil'],
#  ['mushrooms'],
#  ['fava beans', 'fava', 'beans'],
#  ['finely chopped fresh parsley',
#   'finely chopped fresh',
#   'chopped fresh parsley',
#   'finely chopped',
#   'chopped fresh',
#   'fresh parsley',
#   'finely',
#   'chopped',
#   'fresh',
#   'parsley'],
#  ['fresh tarragon', 'fresh', 'tarragon'],
#  ['salt'],
#  ['granulated sugar', 'granulated', 'sugar'],
#  ['eggs'],
#  ['grated lemon zest',
#   'grated lemon',
#   'lemon zest',
#   'grated',
#   'lemon',
#   'zest'],
#  ['cake flour', 'cake', 'flour'],
#  ['chopped almonds', 'chopped', 'almonds'],
#  ['dried oregano', 'dried', 'oregano'],
#  ['dried basil', 'dried', 'basil'],
#  ['broccoli'],
#  ['grated parmesan cheese',
#   'grated parmesan',
#   'parmesan cheese',
#   'grated',
#   'parmesan',
#   'cheese'],
#  ['dry bread crumbs', 'dry bread', 'bread crumbs', 'dry', 'bread', 'crumbs'],
#  ['pepper'],
#  ['salt'],
#  ['potatoes'],
#  ['eggs'],
#  ['purpose flour', 'purpose', 'flour'],
#  ['self rising flour',
#   'self rising',
#   'rising flour',
#   'self',
#   'rising',
#   'flour'],
#  ['eggplant'],
#  ['fresh basil leaves',
#   'fresh basil',
#   'basil leaves',
#   'fresh',
#   'basil',
#   'leaves'],
#  ['cooking spray', 'cooking', 'spray'],
#  ['chicken'],
#  ['pitas'],
#  ['plum tomatoes', 'plum', 'tomatoes'],
#  ['goat cheese', 'goat', 'cheese'],
#  ['ground black pepper',
#   'ground black',
#   'black pepper',
#   'ground',
#   'black',
#   'pepper'],
#  ['reduced fat milk', 'reduced fat', 'fat milk', 'reduced', 'fat', 'milk'],
#  ['smoked trout', 'smoked', 'trout'],
#  ['large egg whites', 'large egg', 'egg whites', 'large', 'egg', 'whites'],
#  ['large eggs', 'large', 'eggs'],
#  ['salt'],
#  ['fresh dill', 'fresh', 'dill'],
#  ['parmigiano reggiano cheese',
#   'parmigiano reggiano',
#   'reggiano cheese',
#   'parmigiano',
#   'reggiano',
#   'cheese'],
#  ['green onions', 'green', 'onions'],
#  ['asparagus'],
#  ['cooking spray', 'cooking', 'spray'],
#  ['canola oil', 'canola', 'oil'],
#  ['large egg whites', 'large egg', 'egg whites', 'large', 'egg', 'whites'],
#  ['oil'],
#  ['kosher salt', 'kosher', 'salt'],
#  ['ground black pepper',
#   'ground black',
#   'black pepper',
#   'ground',
#   'black',
#   'pepper'],
#  ['cream tartar', 'cream', 'tartar'],
#  ['olive oil', 'olive', 'oil'],
#  ['fresh parsley', 'fresh', 'parsley'],
#  ['ricotta salata', 'ricotta', 'salata'],
#  ['green onions', 'green', 'onions'],
#  ['unsalted butter', 'unsalted', 'butter'],
#  ['pecorino cheese', 'pecorino', 'cheese'],
#  ['grana padano', 'grana', 'padano'],
#  ['pasta'],
#  ['cracked black pepper',
#   'cracked black',
#   'black pepper',
#   'cracked',
#   'black',
#   'pepper'],
#  ['kosher salt', 'kosher', 'salt'],
#  ['green bell pepper', 'green bell', 'bell pepper', 'green', 'bell', 'pepper'],
#  ['garlic'],
#  ['shredded mozzarella cheese',
#   'shredded mozzarella',
#   'mozzarella cheese',
#   'shredded',
#   'mozzarella',
#   'cheese'],
#  ['vidalia onion', 'vidalia', 'onion'],
#  ['marinara sauce', 'marinara', 'sauce'],
#  ['baby carrots', 'baby', 'carrots'],
#  ['pepper'],
#  ['salt'],
#  ['smoked gouda', 'smoked', 'gouda'],
#  ['baby spinach leaves',
#   'baby spinach',
#   'spinach leaves',
#   'baby',
#   'spinach',
#   'leaves'],
#  ['shredded sharp cheddar cheese',
#   'shredded sharp cheddar',
#   'sharp cheddar cheese',
#   'shredded sharp',
#   'sharp cheddar',
#   'cheddar cheese',
#   'shredded',
#   'sharp',
#   'cheddar',
#   'cheese'],
#  ['small red potato', 'small red', 'red potato', 'small', 'red', 'potato'],
#  ['bertolli classico olive oil',
#   'bertolli classico olive',
#   'classico olive oil',
#   'bertolli classico',
#   'classico olive',
#   'olive oil',
#   'bertolli',
#   'classico',
#   'olive',
#   'oil'],
#  ['boneless skinless chicken breast halves',
#   'boneless skinless chicken breast',
#   'skinless chicken breast halves',
#   'boneless skinless chicken',
#   'skinless chicken breast',
#   'chicken breast halves',
#   'boneless skinless',
#   'skinless chicken',
#   'chicken breast',
#   'breast halves',
#   'boneless',
#   'skinless',
#   'chicken',
#   'breast',
#   'halves'],
#  ['eggs'],
#  ['linguine'],
#  ['chicken broth', 'chicken', 'broth'],
#  ['bacon crisp cooked crumbled',
#   'bacon crisp cooked',
#   'crisp cooked crumbled',
#   'bacon crisp',
#   'crisp cooked',
#   'cooked crumbled',
#   'bacon',
#   'crisp',
#   'cooked',
#   'crumbled'],
#  ['bertolli vineyard premium collect marinara burgundi wine sauc',
#   'bertolli vineyard premium collect marinara burgundi wine',
#   'vineyard premium collect marinara burgundi wine sauc',
#   'bertolli vineyard premium collect marinara burgundi',
#   'vineyard premium collect marinara burgundi wine',
#   'premium collect marinara burgundi wine sauc',
#   'bertolli vineyard premium collect marinara',
#   'vineyard premium collect marinara burgundi',
#   'premium collect marinara burgundi wine',
#   'collect marinara burgundi wine sauc',
#   'bertolli vineyard premium collect',
#   'vineyard premium collect marinara',
#   'premium collect marinara burgundi',
#   'collect marinara burgundi wine',
#   'marinara burgundi wine sauc',
#   'bertolli vineyard premium',
#   'vineyard premium collect',
#   'premium collect marinara',
#   'collect marinara burgundi',
#   'marinara burgundi wine',
#   'burgundi wine sauc',
#   'bertolli vineyard',
#   'vineyard premium',
#   'premium collect',
#   'collect marinara',
#   'marinara burgundi',
#   'burgundi wine',
#   'wine sauc',
#   'bertolli',
#   'vineyard',
#   'premium',
#   'collect',
#   'marinara',
#   'burgundi',
#   'wine',
#   'sauc'],
#  ['bread crumb fresh',
#   'bread crumb',
#   'crumb fresh',
#   'bread',
#   'crumb',
#   'fresh'],
#  ['shredded mozzarella cheese',
#   'shredded mozzarella',
#   'mozzarella cheese',
#   'shredded',
#   'mozzarella',
#   'cheese'],
#  ['oz tomato sauce', 'oz tomato', 'tomato sauce', 'oz', 'tomato', 'sauce'],
#  ['ground veal', 'ground', 'veal'],
#  ['sliced mushrooms', 'sliced', 'mushrooms'],
#  ['italian seasoning mix',
#   'italian seasoning',
#   'seasoning mix',
#   'italian',
#   'seasoning',
#   'mix'],
#  ['finely chopped onion',
#   'finely chopped',
#   'chopped onion',
#   'finely',
#   'chopped',
#   'onion'],
#  ['dry bread crumbs', 'dry bread', 'bread crumbs', 'dry', 'bread', 'crumbs'],
#  ['spaghetti'],
#  ['beef'],
#  ['diced tomatoes', 'diced', 'tomatoes'],
#  ['fresh basil leaves',
#   'fresh basil',
#   'basil leaves',
#   'fresh',
#   'basil',
#   'leaves'],
#  ['parmesan cheese', 'parmesan', 'cheese'],
#  ['large eggs', 'large', 'eggs'],
#  ['fat skimmed chicken broth',
#   'fat skimmed chicken',
#   'skimmed chicken broth',
#   'fat skimmed',
#   'skimmed chicken',
#   'chicken broth',
#   'fat',
#   'skimmed',
#   'chicken',
#   'broth'],
#  ['solid pack pumpkin',
#   'solid pack',
#   'pack pumpkin',
#   'solid',
#   'pack',
#   'pumpkin'],
#  ['dry white wine', 'dry white', 'white wine', 'dry', 'white', 'wine'],
#  ['corn starch', 'corn', 'starch'],
#  ['ground nutmeg', 'ground', 'nutmeg'],
#  ['white rice', 'white', 'rice'],
#  ['chicken broth', 'chicken', 'broth'],
#  ['grated parmesan cheese',
#   'grated parmesan',
#   'parmesan cheese',
#   'grated',
#   'parmesan',
#   'cheese'],
#  ['salt'],
#  ['ground pepper', 'ground', 'pepper'],
#  ['butter'],
#  ['onions'],
#  ['fresh rosemary', 'fresh', 'rosemary'],
#  ['fresh thyme leaves',
#   'fresh thyme',
#   'thyme leaves',
#   'fresh',
#   'thyme',
#   'leaves'],
#  ['flat leaf parsley', 'flat leaf', 'leaf parsley', 'flat', 'leaf', 'parsley'],
#  ['olive oil', 'olive', 'oil'],
#  ['baby carrots', 'baby', 'carrots'],
#  ['kosher salt', 'kosher', 'salt'],
#  ['balsamic vinegar', 'balsamic', 'vinegar'],
#  ['onions'],
#  ['ground black pepper',
#   'ground black',
#   'black pepper',
#   'ground',
#   'black',
#   'pepper'],
#  ['small red potato', 'small red', 'red potato', 'small', 'red', 'potato'],
#  ['pistachios'],
#  ['salt'],
#  ['dried cherry', 'dried', 'cherry'],
#  ['butter'],
#  ['large eggs', 'large', 'eggs'],
#  ['vanilla extract', 'vanilla', 'extract'],
#  ['sugar'],
#  ['baking powder', 'baking', 'powder'],
#  ['purpose flour', 'purpose', 'flour'],
#  ['pepper'],
#  ['garlic'],
#  ['eggs'],
#  ['grated parmesan cheese',
#   'grated parmesan',
#   'parmesan cheese',
#   'grated',
#   'parmesan',
#   'cheese'],
#  ['fresh parsley', 'fresh', 'parsley'],
#  ['prosciutto'],
#  ['salt'],
#  ['romano cheese', 'romano', 'cheese'],
#  ['ricotta cheese', 'ricotta', 'cheese'],
#  ['kosher salt', 'kosher', 'salt'],
#  ['butter'],
#  ['garlic'],
#  ['dry white wine', 'dry white', 'white wine', 'dry', 'white', 'wine'],
#  ['extra virgin olive oil',
#   'extra virgin olive',
#   'virgin olive oil',
#   'extra virgin',
#   'virgin olive',
#   'olive oil',
#   'extra',
#   'virgin',
#   'olive',
#   'oil'],
#  ['parsley leaves', 'parsley', 'leaves'],
#  ['lemon'],
#  ['shrimp'],
#  ['black pepper', 'black', 'pepper'],
#  ['shallots'],
#  ['linguine'],
#  ['water'],
#  ['fresh lemon juice',
#   'fresh lemon',
#   'lemon juice',
#   'fresh',
#   'lemon',
#   'juice'],
#  ['fresh raspberries', 'fresh', 'raspberries'],
#  ['sugar'],
#  ['dry vermouth', 'dry', 'vermouth'],
#  ['flour'],
#  ['salt'],
#  ['canned low sodium chicken broth',
#   'canned low sodium chicken',
#   'low sodium chicken broth',
#   'canned low sodium',
#   'low sodium chicken',
#   'sodium chicken broth',
#   'canned low',
#   'low sodium',
#   'sodium chicken',
#   'chicken broth',
#   'canned',
#   'low',
#   'sodium',
#   'chicken',
#   'broth'],
#  ['ground black pepper',
#   'ground black',
#   'black pepper',
#   'ground',
#   'black',
#   'pepper'],
#  ['garlic'],
#  ['pinenuts'],
#  ['butter'],
#  ['chicken livers', 'chicken', 'livers'],
#  ['olive oil', 'olive', 'oil'],
#  ['raisins'],
#  ['flat leaf parsley', 'flat leaf', 'leaf parsley', 'flat', 'leaf', 'parsley'],
#  ['seasoned bread crumbs',
#   'seasoned bread',
#   'bread crumbs',
#   'seasoned',
#   'bread',
#   'crumbs'],
#  ['grated parmesan cheese',
#   'grated parmesan',
#   'parmesan cheese',
#   'grated',
#   'parmesan',
#   'cheese'],
#  ['salt'],
#  ['fresh parsley', 'fresh', 'parsley'],
#  ['chicken broth', 'chicken', 'broth'],
#  ['minced garlic', 'minced', 'garlic'],
#  ['half half', 'half', 'half'],
#  ['shredded mozzarella cheese',
#   'shredded mozzarella',
#   'mozzarella cheese',
#   'shredded',
#   'mozzarella',
#   'cheese'],
#  ['frozen chopped spinach',
#   'frozen chopped',
#   'chopped spinach',
#   'frozen',
#   'chopped',
#   'spinach'],
#  ['pepper'],
#  ['flour'],
#  ['penne pasta', 'penne', 'pasta'],
#  ['black pepper', 'black', 'pepper'],
#  ['large eggs', 'large', 'eggs'],
#  ['butter'],
#  ['ground beef', 'ground', 'beef'],
#  ['jack cheese', 'jack', 'cheese'],
#  ['vegetables'],
#  ['dry white wine', 'dry white', 'white wine', 'dry', 'white', 'wine'],
#  ['lemon juice', 'lemon', 'juice'],
#  ['arborio rice', 'arborio', 'rice'],
#  ['olive oil', 'olive', 'oil'],
#  ['unsalted butter', 'unsalted', 'butter'],
#  ['ricotta'],
#  ['pepper'],
#  ['asparagus'],
#  ['yellow onion', 'yellow', 'onion'],
#  ['frozen peas', 'frozen', 'peas'],
#  ['reduced sodium chicken broth',
#   'reduced sodium chicken',
#   'sodium chicken broth',
#   'reduced sodium',
#   'sodium chicken',
#   'chicken broth',
#   'reduced',
#   'sodium',
#   'chicken',
#   'broth'],
#  ['prosciutto'],
#  ['salt'],
#  ['chopped fresh mint',
#   'chopped fresh',
#   'fresh mint',
#   'chopped',
#   'fresh',
#   'mint'],
#  ['sugar'],
#  ['linguine'],
#  ['boneless skinless chicken breast halves',
#   'boneless skinless chicken breast',
#   'skinless chicken breast halves',
#   'boneless skinless chicken',
#   'skinless chicken breast',
#   'chicken breast halves',
#   'boneless skinless',
#   'skinless chicken',
#   'chicken breast',
#   'breast halves',
#   'boneless',
#   'skinless',
#   'chicken',
#   'breast',
#   'halves'],
#  ['balsamic vinegar', 'balsamic', 'vinegar'],
#  ['oil'],
#  ['fresh basil', 'fresh', 'basil'],
#  ['large garlic cloves',
#   'large garlic',
#   'garlic cloves',
#   'large',
#   'garlic',
#   'cloves'],
#  ['low salt chicken broth',
#   'low salt chicken',
#   'salt chicken broth',
#   'low salt',
#   'salt chicken',
#   'chicken broth',
#   'low',
#   'salt',
#   'chicken',
#   'broth'],
#  ['olive oil', 'olive', 'oil'],
#  ['purple onion', 'purple', 'onion'],
#  ['eggplant'],
#  ['low sodium chicken broth',
#   'low sodium chicken',
#   'sodium chicken broth',
#   'low sodium',
#   'sodium chicken',
#   'chicken broth',
#   'low',
#   'sodium',
#   'chicken',
#   'broth'],
#  ['fresh basil leaves',
#   'fresh basil',
#   'basil leaves',
#   'fresh',
#   'basil',
#   'leaves'],
#  ['pepper'],
#  ['grated parmesan cheese',
#   'grated parmesan',
#   'parmesan cheese',
#   'grated',
#   'parmesan',
#   'cheese'],
#  ['goat cheese', 'goat', 'cheese'],
#  ['zucchini'],
#  ['salt'],
#  ['polenta'],
#  ['water'],
#  ['bell pepper', 'bell', 'pepper'],
#  ['olive oil cooking spray',
#   'olive oil cooking',
#   'oil cooking spray',
#   'olive oil',
#   'oil cooking',
#   'cooking spray',
#   'olive',
#   'oil',
#   'cooking',
#   'spray'],
#  ['black pepper', 'black', 'pepper'],
#  ['bacon'],
#  ['grated parmesan cheese',
#   'grated parmesan',
#   'parmesan cheese',
#   'grated',
#   'parmesan',
#   'cheese'],
#  ['flat leaf parsley', 'flat leaf', 'leaf parsley', 'flat', 'leaf', 'parsley'],
#  ['kosher salt', 'kosher', 'salt'],
#  ['linguine'],
#  ['egg yolks', 'egg', 'yolks'],
#  ['extra virgin olive oil',
#   'extra virgin olive',
#   'virgin olive oil',
#   'extra virgin',
#   'virgin olive',
#   'olive oil',
#   'extra',
#   'virgin',
#   'olive',
#   'oil'],
#  ['fresh rosemary', 'fresh', 'rosemary'],
#  ['duck breast halves',
#   'duck breast',
#   'breast halves',
#   'duck',
#   'breast',
#   'halves'],
#  ['fennel seeds', 'fennel', 'seeds'],
#  ['garlic cloves', 'garlic', 'cloves'],
#  ['roma tomatoes', 'roma', 'tomatoes'],
#  ['pizza crust', 'pizza', 'crust'],
#  ['goat cheese', 'goat', 'cheese'],
#  ['pesto sauce', 'pesto', 'sauce'],
#  ['garlic'],
#  ['olive oil', 'olive', 'oil'],
#  ['arugula'],
#  ['bell pepper', 'bell', 'pepper'],
#  ['purple onion', 'purple', 'onion'],
#  ['fresh lemon juice',
#   'fresh lemon',
#   'lemon juice',
#   'fresh',
#   'lemon',
#   'juice'],
#  ['tomatoes'],
#  ['summer squash', 'summer', 'squash'],
#  ['garlic cloves', 'garlic', 'cloves'],
#  ['flat leaf parsley', 'flat leaf', 'leaf parsley', 'flat', 'leaf', 'parsley'],
#  ['red wine vinegar', 'red wine', 'wine vinegar', 'red', 'wine', 'vinegar'],
#  ['ciabatta'],
#  ['juice'],
#  ['capers'],
#  ['extra virgin olive oil',
#   'extra virgin olive',
#   'virgin olive oil',
#   'extra virgin',
#   'virgin olive',
#   'olive oil',
#   'extra',
#   'virgin',
#   'olive',
#   'oil'],
#  ['fresh herbs', 'fresh', 'herbs'],
#  ['grated lemon peel',
#   'grated lemon',
#   'lemon peel',
#   'grated',
#   'lemon',
#   'peel'],
#  ['dough'],
#  ['cracked black pepper',
#   'cracked black',
#   'black pepper',
#   'cracked',
#   'black',
#   'pepper'],
#  ['coarse sea salt', 'coarse sea', 'sea salt', 'coarse', 'sea', 'salt'],
#  ['lemon'],
#  ['olive oil flavored cooking spray',
#   'olive oil flavored cooking',
#   'oil flavored cooking spray',
#   'olive oil flavored',
#   'oil flavored cooking',
#   'flavored cooking spray',
#   'olive oil',
#   'oil flavored',
#   'flavored cooking',
#   'cooking spray',
#   'olive',
#   'oil',
#   'flavored',
#   'cooking',
#   'spray'],
#  ['pinenuts'],
#  ['rosemary leaves', 'rosemary', 'leaves'],
#  ['prosciutto'],
#  ['mushrooms'],
#  ['salt'],
#  ['grated parmesan cheese',
#   'grated parmesan',
#   'parmesan cheese',
#   'grated',
#   'parmesan',
#   'cheese'],
#  ['red pepper flakes',
#   'red pepper',
#   'pepper flakes',
#   'red',
#   'pepper',
#   'flakes'],
#  ['boneless skinless chicken breast halves',
#   'boneless skinless chicken breast',
#   'skinless chicken breast halves',
#   'boneless skinless chicken',
#   'skinless chicken breast',
#   'chicken breast halves',
#   'boneless skinless',
#   'skinless chicken',
#   'chicken breast',
#   'breast halves',
#   'boneless',
#   'skinless',
#   'chicken',
#   'breast',
#   'halves'],
#  ['water'],
#  ['roma tomatoes', 'roma', 'tomatoes'],
#  ['garlic'],
#  ['dried oregano', 'dried', 'oregano'],
#  ['ground black pepper',
#   'ground black',
#   'black pepper',
#   'ground',
#   'black',
#   'pepper'],
#  ['dry white wine', 'dry white', 'white wine', 'dry', 'white', 'wine'],
#  ['brie cheese', 'brie', 'cheese'],
#  ['cheese ravioli', 'cheese', 'ravioli'],
#  ['evaporated milk', 'evaporated', 'milk'],
#  ['italian seasoned breadcrumbs',
#   'italian seasoned',
#   'seasoned breadcrumbs',
#   'italian',
#   'seasoned',
#   'breadcrumbs'],
#  ['eggs'],
#  ['cheese'],
#  ['parsley'],
#  ['smoked gouda', 'smoked', 'gouda'],
#  ['black pepper', 'black', 'pepper'],
#  ['olive oil', 'olive', 'oil'],
#  ['fat free cottage cheese',
#   'fat free cottage',
#   'free cottage cheese',
#   'fat free',
#   'free cottage',
#   'cottage cheese',
#   'fat',
#   'free',
#   'cottage',
#   'cheese'],
#  ['dried oregano', 'dried', 'oregano'],
#  ['dried basil', 'dried', 'basil'],
#  ['grated parmesan cheese',
#   'grated parmesan',
#   'parmesan cheese',
#   'grated',
#   'parmesan',
#   'cheese'],
#  ['salt'],
#  ['water'],
#  ['part skim mozzarella cheese',
#   'part skim mozzarella',
#   'skim mozzarella cheese',
#   'part skim',
#   'skim mozzarella',
#   'mozzarella cheese',
#   'part',
#   'skim',
#   'mozzarella',
#   'cheese'],
#  ['crushed red pepper',
#   'crushed red',
#   'red pepper',
#   'crushed',
#   'red',
#   'pepper'],
#  ['fresh basil', 'fresh', 'basil'],
#  ['cherry tomatoes', 'cherry', 'tomatoes'],
#  ['cooking spray', 'cooking', 'spray'],
#  ['oven ready lasagna noodles',
#   'oven ready lasagna',
#   'ready lasagna noodles',
#   'oven ready',
#   'ready lasagna',
#   'lasagna noodles',
#   'oven',
#   'ready',
#   'lasagna',
#   'noodles'],
#  ['skim milk', 'skim', 'milk'],
#  ['margarine'],
#  ['garlic'],
#  ['freshly ground pepper',
#   'freshly ground',
#   'ground pepper',
#   'freshly',
#   'ground',
#   'pepper'],
#  ['grated parmesan cheese',
#   'grated parmesan',
#   'parmesan cheese',
#   'grated',
#   'parmesan',
#   'cheese'],
#  ['cream cheese', 'cream', 'cheese'],
#  ['fettucine'],
#  ['purpose flour', 'purpose', 'flour'],
#  ['fresh parsley', 'fresh', 'parsley'],
#  ['chopped fresh thyme',
#   'chopped fresh',
#   'fresh thyme',
#   'chopped',
#   'fresh',
#   'thyme'],
#  ['olive oil', 'olive', 'oil'],
#  ['radicchio'],
#  ['balsamic vinegar', 'balsamic', 'vinegar'],
#  ['garbanzo beans', 'garbanzo', 'beans'],
#  ['large garlic cloves',
#   'large garlic',
#   'garlic cloves',
#   'large',
#   'garlic',
#   'cloves'],
#  ['plum tomatoes', 'plum', 'tomatoes'],
#  ['orzo pasta', 'orzo', 'pasta'],
#  ['fresh parsley', 'fresh', 'parsley'],
#  ['grated parmesan cheese',
#   'grated parmesan',
#   'parmesan cheese',
#   'grated',
#   'parmesan',
#   'cheese'],
#  ['rubbed sage', 'rubbed', 'sage'],
#  ['dried rosemary', 'dried', 'rosemary'],
#  ['olive oil', 'olive', 'oil'],
#  ['canned beef broth', 'canned beef', 'beef broth', 'canned', 'beef', 'broth'],
#  ['onions'],
#  ['kale leaves', 'kale', 'leaves'],
#  ['chicken noodle soup',
#   'chicken noodle',
#   'noodle soup',
#   'chicken',
#   'noodle',
#   'soup'],
#  ['cannellini beans', 'cannellini', 'beans'],
#  ['cherry tomatoes', 'cherry', 'tomatoes'],
#  ['black pepper', 'black', 'pepper'],
#  ['salt'],
#  ['balsamic vinegar', 'balsamic', 'vinegar'],
#  ['mozzarella cheese', 'mozzarella', 'cheese'],
#  ['fresh basil leaves',
#   'fresh basil',
#   'basil leaves',
#   'fresh',
#   'basil',
#   'leaves'],
#  ['white onion', 'white', 'onion'],
#  ['italian style rolls',
#   'italian style',
#   'style rolls',
#   'italian',
#   'style',
#   'rolls'],
#  ['provolone cheese', 'provolone', 'cheese'],
#  ['genoa salami', 'genoa', 'salami'],
#  ['olive oil', 'olive', 'oil'],
#  ['sweet pepper', 'sweet', 'pepper'],
#  ['oregano'],
#  ['pepper'],
#  ['red wine vinegar', 'red wine', 'wine vinegar', 'red', 'wine', 'vinegar'],
#  ['boiled ham', 'boiled', 'ham'],
#  ['tomatoes'],
#  ['capicola'],
#  ['salt'],
#  ['iceberg lettuce', 'iceberg', 'lettuce'],
#  ['navy beans', 'navy', 'beans'],
#  ['jalapeno chilies', 'jalapeno', 'chilies'],
#  ['diced celery', 'diced', 'celery'],
#  ['water'],
#  ['italian salad dressing mix',
#   'italian salad dressing',
#   'salad dressing mix',
#   'italian salad',
#   'salad dressing',
#   'dressing mix',
#   'italian',
#   'salad',
#   'dressing',
#   'mix'],
#  ['chopped cilantro fresh',
#   'chopped cilantro',
#   'cilantro fresh',
#   'chopped',
#   'cilantro',
#   'fresh'],
#  ['cider vinegar', 'cider', 'vinegar'],
#  ['diced tomatoes', 'diced', 'tomatoes'],
#  ['red bell pepper', 'red bell', 'bell pepper', 'red', 'bell', 'pepper'],
#  ['olive oil', 'olive', 'oil'],
#  ['garlic cloves', 'garlic', 'cloves'],
#  ['sliced green onions',
#   'sliced green',
#   'green onions',
#   'sliced',
#   'green',
#   'onions'],
#  ['barbecue sauce', 'barbecue', 'sauce'],
#  ['yellow onion', 'yellow', 'onion'],
#  ['prepared pizza crust',
#   'prepared pizza',
#   'pizza crust',
#   'prepared',
#   'pizza',
#   'crust'],
#  ['boneless skinless chicken breasts',
#   'boneless skinless chicken',
#   'skinless chicken breasts',
#   'boneless skinless',
#   'skinless chicken',
#   'chicken breasts',
#   'boneless',
#   'skinless',
#   'chicken',
#   'breasts'],
#  ['sargento traditional cut shredded mozzarella cheese',
#   'sargento traditional cut shredded mozzarella',
#   'traditional cut shredded mozzarella cheese',
#   'sargento traditional cut shredded',
#   'traditional cut shredded mozzarella',
#   'cut shredded mozzarella cheese',
#   'sargento traditional cut',
#   'traditional cut shredded',
#   'cut shredded mozzarella',
#   'shredded mozzarella cheese',
#   'sargento traditional',
#   'traditional cut',
#   'cut shredded',
#   'shredded mozzarella',
#   'mozzarella cheese',
#   'sargento',
#   'traditional',
#   'cut',
#   'shredded',
#   'mozzarella',
#   'cheese'],
#  ['vegetable oil', 'vegetable', 'oil'],
#  ['vegetables'],
#  ['basil'],
#  ['basil pesto sauce',
#   'basil pesto',
#   'pesto sauce',
#   'basil',
#   'pesto',
#   'sauce'],
#  ['aioli'],
#  ['cooked shrimp', 'cooked', 'shrimp'],
#  ['prosciutto'],
#  ['mozzarella balls', 'mozzarella', 'balls'],
#  ['sun dried tomatoes',
#   'sun dried',
#   'dried tomatoes',
#   'sun',
#   'dried',
#   'tomatoes'],
#  ['salami'],
#  ['boneless skinless chicken breasts',
#   'boneless skinless chicken',
#   'skinless chicken breasts',
#   'boneless skinless',
#   'skinless chicken',
#   'chicken breasts',
#   'boneless',
#   'skinless',
#   'chicken',
#   'breasts'],
#  ['milk'],
#  ['condensed cream mushroom soup',
#   'condensed cream mushroom',
#   'cream mushroom soup',
#   'condensed cream',
#   'cream mushroom',
#   'mushroom soup',
#   'condensed',
#   'cream',
#   'mushroom',
#   'soup'],
#  ['fettuccine pasta', 'fettuccine', 'pasta'],
#  ['butter'],
#  ['grated parmesan cheese',
#   'grated parmesan',
#   'parmesan cheese',
#   'grated',
#   'parmesan',
#   'cheese'],
#  ['broccoli'],
#  ['olive oil', 'olive', 'oil'],
#  ['grated parmesan cheese',
#   'grated parmesan',
#   'parmesan cheese',
#   'grated',
#   'parmesan',
#   'cheese'],
#  ['frozen spinach', 'frozen', 'spinach'],
#  ['lasagne'],
#  ['passata'],
#  ['eggplant'],
#  ['mushrooms'],
#  ['pinenuts'],
#  ['roasted red peppers',
#   'roasted red',
#   'red peppers',
#   'roasted',
#   'red',
#   'peppers'],
#  ['ricotta'],
#  ['ground black pepper',
#   'ground black',
#   'black pepper',
#   'ground',
#   'black',
#   'pepper'],
#  ['parsley'],
#  ['fat free cream cheese',
#   'fat free cream',
#   'free cream cheese',
#   'fat free',
#   'free cream',
#   'cream cheese',
#   'fat',
#   'free',
#   'cream',
#   'cheese'],
#  ['french bread', 'french', 'bread'],
#  ['non fat sour cream',
#   'non fat sour',
#   'fat sour cream',
#   'non fat',
#   'fat sour',
#   'sour cream',
#   'non',
#   'fat',
#   'sour',
#   'cream'],
#  ['green onions', 'green', 'onions'],
#  ['reduced fat swiss cheese',
#   'reduced fat swiss',
#   'fat swiss cheese',
#   'reduced fat',
#   'fat swiss',
#   'swiss cheese',
#   'reduced',
#   'fat',
#   'swiss',
#   'cheese'],
#  ['grated parmesan cheese',
#   'grated parmesan',
#   'parmesan cheese',
#   'grated',
#   'parmesan',
#   'cheese'],
#  ['garlic'],
#  ['fat free mayonnaise',
#   'fat free',
#   'free mayonnaise',
#   'fat',
#   'free',
#   'mayonnaise'],
#  ['black pepper', 'black', 'pepper'],
#  ['cannellini beans', 'cannellini', 'beans'],
#  ['roasted garlic', 'roasted', 'garlic'],
#  ['seasoning'],
#  ['kale'],
#  ['extra virgin olive oil',
#   'extra virgin olive',
#   'virgin olive oil',
#   'extra virgin',
#   'virgin olive',
#   'olive oil',
#   'extra',
#   'virgin',
#   'olive',
#   'oil'],
#  ['fat free less sodium chicken broth',
#   'fat free less sodium chicken',
#   'free less sodium chicken broth',
#   'fat free less sodium',
#   'free less sodium chicken',
#   'less sodium chicken broth',
#   'fat free less',
#   'free less sodium',
#   'less sodium chicken',
#   'sodium chicken broth',
#   'fat free',
#   'free less',
#   'less sodium',
#   'sodium chicken',
#   'chicken broth',
#   'fat',
#   'free',
#   'less',
#   'sodium',
#   'chicken',
#   'broth'],
#  ['diced tomatoes', 'diced', 'tomatoes'],
#  ['italian bread', 'italian', 'bread'],
#  ['sundried tomato paste',
#   'sundried tomato',
#   'tomato paste',
#   'sundried',
#   'tomato',
#   'paste'],
#  ['dried thyme', 'dried', 'thyme'],
#  ['salt'],
#  ['porcini'],
#  ['fresh thyme', 'fresh', 'thyme'],
#  ['garlic cloves', 'garlic', 'cloves'],
#  ['sourdough loaf', 'sourdough', 'loaf'],
#  ['crust'],
#  ['flat leaf parsley', 'flat leaf', 'leaf parsley', 'flat', 'leaf', 'parsley'],
#  ['duck fat', 'duck', 'fat'],
#  ['fine sea salt', 'fine sea', 'sea salt', 'fine', 'sea', 'salt'],
#  ['squabs'],
#  ['confit'],
#  ['fresh lemon juice',
#   'fresh lemon',
#   'lemon juice',
#   'fresh',
#   'lemon',
#   'juice'],
#  ['aged gouda', 'aged', 'gouda'],
#  ['soppressata'],
#  ['tomato paste', 'tomato', 'paste'],
#  ['pepper'],
#  ['dry white wine', 'dry white', 'white wine', 'dry', 'white', 'wine'],
#  ['garlic cloves', 'garlic', 'cloves'],
#  ['boiling water', 'boiling', 'water'],
#  ['black pepper', 'black', 'pepper'],
#  ['grated parmesan cheese',
#   'grated parmesan',
#   'parmesan cheese',
#   'grated',
#   'parmesan',
#   'cheese'],
#  ['salt'],
#  ['boneless skinless chicken breast halves',
#   'boneless skinless chicken breast',
#   'skinless chicken breast halves',
#   'boneless skinless chicken',
#   'skinless chicken breast',
#   'chicken breast halves',
#   'boneless skinless',
#   'skinless chicken',
#   'chicken breast',
#   'breast halves',
#   'boneless',
#   'skinless',
#   'chicken',
#   'breast',
#   'halves'],
#  ['dried porcini mushrooms',
#   'dried porcini',
#   'porcini mushrooms',
#   'dried',
#   'porcini',
#   'mushrooms'],
#  ['sun dried tomatoes',
#   'sun dried',
#   'dried tomatoes',
#   'sun',
#   'dried',
#   'tomatoes'],
#  ['purple onion', 'purple', 'onion'],
#  ['fresh parsley', 'fresh', 'parsley'],
#  ['chicken broth', 'chicken', 'broth'],
#  ['olive oil', 'olive', 'oil'],
#  ['artichokes'],
#  ['fresh lemon juice',
#   'fresh lemon',
#   'lemon juice',
#   'fresh',
#   'lemon',
#   'juice'],
#  ['hot red pepper flakes',
#   'hot red pepper',
#   'red pepper flakes',
#   'hot red',
#   'red pepper',
#   'pepper flakes',
#   'hot',
#   'red',
#   'pepper',
#   'flakes'],
#  ['balsamic vinegar', 'balsamic', 'vinegar'],
#  ['fresh basil leaves',
#   'fresh basil',
#   'basil leaves',
#   'fresh',
#   'basil',
#   'leaves'],
#  ['pasta'],
#  ['prosciutto'],
#  ['garlic cloves', 'garlic', 'cloves'],
#  ['capers'],
#  ['finely chopped onion',
#   'finely chopped',
#   'chopped onion',
#   'finely',
#   'chopped',
#   'onion'],
#  ['juice'],
#  ['olive oil', 'olive', 'oil'],
#  ['anchovy fillets', 'anchovy', 'fillets'],
#  ['fat free less sodium chicken broth',
#   'fat free less sodium chicken',
#   'free less sodium chicken broth',
#   'fat free less sodium',
#   'free less sodium chicken',
#   'less sodium chicken broth',
#   'fat free less',
#   'free less sodium',
#   'less sodium chicken',
#   'sodium chicken broth',
#   'fat free',
#   'free less',
#   'less sodium',
#   'sodium chicken',
#   'chicken broth',
#   'fat',
#   'free',
#   'less',
#   'sodium',
#   'chicken',
#   'broth'],
#  ['dry white wine', 'dry white', 'white wine', 'dry', 'white', 'wine'],
#  ['fresh lemon juice',
#   'fresh lemon',
#   'lemon juice',
#   'fresh',
#   'lemon',
#   'juice'],
#  ['capers'],
#  ['olive oil', 'olive', 'oil'],
#  ['butter'],
#  ['black pepper', 'black', 'pepper'],
#  ['broccoli rabe', 'broccoli', 'rabe'],
#  ['lemon slices', 'lemon', 'slices'],
#  ['seasoned bread crumbs',
#   'seasoned bread',
#   'bread crumbs',
#   'seasoned',
#   'bread',
#   'crumbs'],
#  ['chicken cutlets', 'chicken', 'cutlets'],
#  ['fresh parsley', 'fresh', 'parsley'],
#  ['saffron threads', 'saffron', 'threads'],
#  ['olive oil', 'olive', 'oil'],
#  ['dry white wine', 'dry white', 'white wine', 'dry', 'white', 'wine'],
#  ['grape tomatoes', 'grape', 'tomatoes'],
#  ['parmigiano reggiano cheese',
#   'parmigiano reggiano',
#   'reggiano cheese',
#   'parmigiano',
#   'reggiano',
#   'cheese'],
#  ['salt'],
#  ['fresh rosemary', 'fresh', 'rosemary'],
#  ['unsalted butter', 'unsalted', 'butter'],
#  ['orzo'],
#  ['black pepper', 'black', 'pepper'],
#  ['veal chops', 'veal', 'chops'],
#  ['garlic cloves', 'garlic', 'cloves'],
#  ['grated parmesan cheese',
#   'grated parmesan',
#   'parmesan cheese',
#   'grated',
#   'parmesan',
#   'cheese'],
#  ['extra virgin olive oil',
#   'extra virgin olive',
#   'virgin olive oil',
#   'extra virgin',
#   'virgin olive',
#   'olive oil',
#   'extra',
#   'virgin',
#   'olive',
#   'oil'],
#  ['pepper'],
#  ['red wine vinegar', 'red wine', 'wine vinegar', 'red', 'wine', 'vinegar'],
#  ['fresh oregano', 'fresh', 'oregano'],
#  ['oil cured olives', 'oil cured', 'cured olives', 'oil', 'cured', 'olives'],
#  ['green onions', 'green', 'onions'],
#  ['salt'],
#  ['garbanzo beans', 'garbanzo', 'beans'],
#  ['pasta rotel', 'pasta', 'rotel'],
#  ['fresh parsley', 'fresh', 'parsley'],
#  ['parmesan cheese', 'parmesan', 'cheese'],
#  ['garlic'],
#  ['pasta water', 'pasta', 'water'],
#  ['chicken broth', 'chicken', 'broth'],
#  ['boneless skinless chicken breasts',
#   'boneless skinless chicken',
#   'skinless chicken breasts',
#   'boneless skinless',
#   'skinless chicken',
#   'chicken breasts',
#   'boneless',
#   'skinless',
#   'chicken',
#   'breasts'],
#  ['salt'],
#  ['onions'],
#  ['unsalted butter', 'unsalted', 'butter'],
#  ['cooking wine', 'cooking', 'wine'],
#  ['fresh parsley', 'fresh', 'parsley'],
#  ['pepper'],
#  ['heavy cream', 'heavy', 'cream'],
#  ['sliced mushrooms', 'sliced', 'mushrooms'],
#  ['parmigiano reggiano cheese',
#   'parmigiano reggiano',
#   'reggiano cheese',
#   'parmigiano',
#   'reggiano',
#   'cheese'],
#  ['crusty bread', 'crusty', 'bread'],
#  ['parsley'],
#  ['eggs'],
#  ['marinara sauce', 'marinara', 'sauce'],
#  ['mozzarella cheese', 'mozzarella', 'cheese'],
#  ['fresh tomatoes', 'fresh', 'tomatoes'],
#  ['diced tomatoes', 'diced', 'tomatoes'],
#  ['onions'],
#  ['olive oil', 'olive', 'oil'],
#  ['garlic'],
#  ['tomato sauce', 'tomato', 'sauce'],
#  ['uncooked rigatoni', 'uncooked', 'rigatoni'],
#  ['fresh basil', 'fresh', 'basil'],
#  ['grating cheese', 'grating', 'cheese'],
#  ['salt'],
#  ['arborio rice', 'arborio', 'rice'],
#  ['ground black pepper',
#   'ground black',
#   'black pepper',
#   'ground',
#   'black',
#   'pepper'],
#  ['onions'],
#  ['sun dried tomatoes',
#   'sun dried',
#   'dried tomatoes',
#   'sun',
#   'dried',
#   'tomatoes'],
#  ['vegetable stock', 'vegetable', 'stock'],
#  ['dried thyme', 'dried', 'thyme'],
#  ['zucchini'],
#  ['fresh basil leaves',
#   'fresh basil',
#   'basil leaves',
#   'fresh',
#   'basil',
#   'leaves'],
#  ['freshly grated parmesan',
#   'freshly grated',
#   'grated parmesan',
#   'freshly',
#   'grated',
#   'parmesan'],
#  ['butter'],
#  ['arborio rice', 'arborio', 'rice'],
#  ['olive oil', 'olive', 'oil'],
#  ['brie cheese', 'brie', 'cheese'],
#  ['reduced sodium chicken broth',
#   'reduced sodium chicken',
#   'sodium chicken broth',
#   'reduced sodium',
#   'sodium chicken',
#   'chicken broth',
#   'reduced',
#   'sodium',
#   'chicken',
#   'broth'],
#  ['dry white wine', 'dry white', 'white wine', 'dry', 'white', 'wine'],
#  ['cauliflower'],
#  ['water'],
#  ['florets'],
#  ['sliced almonds', 'sliced', 'almonds'],
#  ['unsalted butter', 'unsalted', 'butter'],
#  ['thyme sprigs', 'thyme', 'sprigs'],
#  ['salt'],
#  ['egg whites', 'egg', 'whites'],
#  ['margarine'],
#  ['baking powder', 'baking', 'powder'],
#  ['greek yogurt', 'greek', 'yogurt'],
#  ['milk'],
#  ['purpose flour', 'purpose', 'flour'],
#  ['penne'],
#  ['garlic'],
#  ['eggplant'],
#  ['lemon juice', 'lemon', 'juice'],
#  ['olive oil', 'olive', 'oil'],
#  ['salt'],
#  ['ground black pepper',
#   'ground black',
#   'black pepper',
#   'ground',
#   'black',
#   'pepper'],
#  ['fresh parsley', 'fresh', 'parsley'],
#  ['cold water', 'cold', 'water'],
#  ['dry white wine', 'dry white', 'white wine', 'dry', 'white', 'wine'],
#  ['fish fillets', 'fish', 'fillets'],
#  ['chopped onion', 'chopped', 'onion'],
#  ['olive oil', 'olive', 'oil'],
#  ['fresh parsley', 'fresh', 'parsley'],
#  ['tomatoes'],
#  ['large garlic cloves',
#   'large garlic',
#   'garlic cloves',
#   'large',
#   'garlic',
#   'cloves'],
#  ['large eggs', 'large', 'eggs'],
#  ['whipping cream', 'whipping', 'cream'],
#  ['ground nutmeg', 'ground', 'nutmeg'],
#  ['chopped fresh chives',
#   'chopped fresh',
#   'fresh chives',
#   'chopped',
#   'fresh',
#   'chives'],
#  ['purpose flour', 'purpose', 'flour'],
#  ['grated parmesan cheese',
#   'grated parmesan',
#   'parmesan cheese',
#   'grated',
#   'parmesan',
#   'cheese'],
#  ['salt'],
#  ['ground black pepper',
#   'ground black',
#   'black pepper',
#   'ground',
#   'black',
#   'pepper'],
#  ['russet potatoes', 'russet', 'potatoes'],
#  ['crumbled gorgonzola', 'crumbled', 'gorgonzola'],
#  ['fontina cheese', 'fontina', 'cheese'],
#  ['russet potatoes', 'russet', 'potatoes'],
#  ['eggs'],
#  ['purpose flour', 'purpose', 'flour'],
#  ['ground nutmeg', 'ground', 'nutmeg'],
#  ['spinach leaves', 'spinach', 'leaves'],
#  ['butter'],
#  ['tomato paste', 'tomato', 'paste'],
#  ['orange'],
#  ['extra virgin olive oil',
#   'extra virgin olive',
#   'virgin olive oil',
#   'extra virgin',
#   'virgin olive',
#   'olive oil',
#   'extra',
#   'virgin',
#   'olive',
#   'oil'],
#  ['lamb shanks', 'lamb', 'shanks'],
#  ['bay leaves', 'bay', 'leaves'],
#  ['low salt chicken broth',
#   'low salt chicken',
#   'salt chicken broth',
#   'low salt',
#   'salt chicken',
#   'chicken broth',
#   'low',
#   'salt',
#   'chicken',
#   'broth'],
#  ['clove'],
#  ['dried porcini mushrooms',
#   'dried porcini',
#   'porcini mushrooms',
#   'dried',
#   'porcini',
#   'mushrooms'],
#  ['dry red wine', 'dry red', 'red wine', 'dry', 'red', 'wine'],
#  ['polenta'],
#  ['rosemary sprigs', 'rosemary', 'sprigs'],
#  ['finely chopped onion',
#   'finely chopped',
#   'chopped onion',
#   'finely',
#   'chopped',
#   'onion'],
#  ['hot water', 'hot', 'water'],
#  ['olive oil', 'olive', 'oil'],
#  ['flat leaf parsley', 'flat leaf', 'leaf parsley', 'flat', 'leaf', 'parsley'],
#  ['grated parmesan cheese',
#   'grated parmesan',
#   'parmesan cheese',
#   'grated',
#   'parmesan',
#   'cheese'],
#  ['garlic cloves', 'garlic', 'cloves'],
#  ['chopped tomatoes', 'chopped', 'tomatoes'],
#  ['spaghetti'],
#  ...]

# %%
def get_italian_kb(italian, ingredients_kb):
    italian_kb = {}
    
    italian_grams = get_ngrams(italian)

    for category in ingredients_kb:
        counter = Counter()
        l = [ps.stem(j) for j in ingredients_kb[category]]
        
        for i in italian_grams:
            for j in i:
                if ps.stem(j) in l:                    
                    counter[j] += 1
                    break
                
        if counter:
            italian_kb[category] = counter.most_common()
            
    return italian_kb

# %%
with open('to_italian_kb.json') as json_file:
    ingredients_kb = json.load(json_file)

# %%
ps = PorterStemmer()

# %%
italian_kb = get_italian_kb(temp, ingredients_kb)

# %%
with open('italian_freq.json', 'w') as f:
    json.dump(italian_kb, f)

# %%
italian_kb
# Out:
# {'carb': [('pasta', 815),
#   ('bread', 456),
#   ('rice', 338),
#   ('spaghetti', 337),
#   ('bread crumbs', 300),
#   ('lasagna', 273),
#   ('penne', 263),
#   ('linguine', 196),
#   ('wheat', 173),
#   ('baguette', 144),
#   ('polenta', 139),
#   ('fettucine', 136),
#   ('doughs', 103),
#   ('bread crumb', 85),
#   ('dough', 85),
#   ('cornmeal', 78),
#   ('crust', 77),
#   ('noodles', 66),
#   ('rolls', 61),
#   ('toasted', 54),
#   ('fettuccine', 52),
#   ('breadcrumbs', 51),
#   ('sourdough', 40),
#   ('macaroni', 34),
#   ('grain', 34),
#   ('manicotti', 28),
#   ('risotto', 20),
#   ('croutons', 20),
#   ('shells', 19),
#   ('tagliatelle', 19),
#   ('barley', 17),
#   ('vermicelli', 16),
#   ('buns', 15),
#   ('shell', 14),
#   ('crusts', 14),
#   ('tortillas', 13),
#   ('quinoa', 10),
#   ('biscuits', 10),
#   ('stuffed', 10),
#   ('shelled', 9),
#   ('oats', 8),
#   ('crackers', 7),
#   ('pita', 7),
#   ('roll', 7),
#   ('couscous', 6),
#   ('toast', 6),
#   ('pitas', 5),
#   ('graham', 5),
#   ('stuffing', 5),
#   ('muffins', 4),
#   ('cornflake', 4),
#   ('biscuit', 4),
#   ('tortilla', 3),
#   ('penn', 3),
#   ('muffin', 3),
#   ('cornbread', 3),
#   ('grits', 3),
#   ('cannelloni', 2),
#   ('tapioca', 2),
#   ('bagels', 2),
#   ('bulgur', 2),
#   ('shortbread', 2),
#   ('cornflakes', 2),
#   ('cereal', 2),
#   ('bun', 2),
#   ('noodle', 1),
#   ('popcorn', 1),
#   ('pancake', 1),
#   ('toasts', 1),
#   ('oat', 1),
#   ('hominy', 1),
#   ('breadcrumb', 1),
#   ('crouton', 1),
#   ('matzo', 1)],
#  'protein': [('chicken', 1825),
#   ('eggs', 1266),
#   ('beef', 577),
#   ('egg', 527),
#   ('sausage', 357),
#   ('prosciutto', 257),
#   ('bacon', 232),
#   ('pork', 230),
#   ('turkey', 184),
#   ('pancetta', 156),
#   ('roasted', 152),
#   ('ribs', 130),
#   ('veal', 129),
#   ('goat', 128),
#   ('sausages', 100),
#   ('ham', 97),
#   ('pepperoni', 89),
#   ('salami', 67),
#   ('tuna', 60),
#   ('meat', 56),
#   ('roast', 55),
#   ('lamb', 36),
#   ('round', 35),
#   ('salmon', 32),
#   ('meatballs', 32),
#   ('fish', 31),
#   ('sirloin', 27),
#   ('steak', 26),
#   ('rib', 26),
#   ('sausag', 23),
#   ('bass', 15),
#   ('cod', 14),
#   ('halibut', 14),
#   ('swordfish', 13),
#   ('steaks', 10),
#   ('tilapia', 10),
#   ('roasting', 8),
#   ('snapper', 8),
#   ('duck', 7),
#   ('hash', 6),
#   ('albacore', 6),
#   ('chorizo', 6),
#   ('trout', 5),
#   ('mortadella', 5),
#   ('flounder', 5),
#   ('hens', 5),
#   ('liver', 4),
#   ('whitefish', 4),
#   ('rounds', 3),
#   ('grouper', 3),
#   ('quail', 3),
#   ('catfish', 3),
#   ('dogs', 2),
#   ('chickens', 2),
#   ('dog', 2),
#   ('kielbasa', 2),
#   ('snappers', 1),
#   ('meats', 1),
#   ('sole', 1),
#   ('mignon', 1),
#   ('burger', 1),
#   ('mincemeat', 1),
#   ('mackerel', 1),
#   ('pig', 1),
#   ('venison', 1),
#   ('giblet', 1),
#   ('shark', 1),
#   ('tripe', 1),
#   ('haddock', 1)],
#  'seafood': [('shrimp', 251),
#   ('anchovy', 183),
#   ('clams', 95),
#   ('scallops', 63),
#   ('tuna', 60),
#   ('clam', 42),
#   ('mussels', 40),
#   ('salmon', 32),
#   ('squid', 32),
#   ('fish', 31),
#   ('crab', 25),
#   ('anchovies', 19),
#   ('bass', 15),
#   ('lobster', 14),
#   ('cod', 14),
#   ('halibut', 14),
#   ('swordfish', 13),
#   ('crabmeat', 11),
#   ('tilapia', 10),
#   ('calamari', 9),
#   ('snapper', 8),
#   ('crabs', 7),
#   ('oyster', 6),
#   ('albacore', 6),
#   ('trout', 5),
#   ('prawns', 5),
#   ('flounder', 5),
#   ('seafood', 5),
#   ('whitefish', 4),
#   ('oysters', 3),
#   ('grouper', 3),
#   ('catfish', 3),
#   ('snappers', 1),
#   ('lobsters', 1),
#   ('sole', 1),
#   ('shellfish', 1),
#   ('mackerel', 1),
#   ('shark', 1),
#   ('haddock', 1)],
#  'cheese': [('parmesan', 2456),
#   ('mozzarella', 1249),
#   ('cheese', 1196),
#   ('ricotta', 665),
#   ('parmigiano', 361),
#   ('provolone', 139),
#   ('mascarpone', 124),
#   ('cheddar', 116),
#   ('feta', 108),
#   ('swiss', 84),
#   ('rigatoni', 81),
#   ('gorgonzola', 60),
#   ('tortellini', 22),
#   ('bocconcini', 17),
#   ('gouda', 15),
#   ('brie', 14)],
#  'dairy': [('milk', 695),
#   ('cream', 678),
#   ('cream cheese', 188),
#   ('sour cream', 111),
#   ('cottage cheese', 107),
#   ('buttermilk', 48),
#   ('yogurt', 33),
#   ('evaporated milk', 19),
#   ('whipped cream', 17),
#   ('condensed milk', 9),
#   ('coconut milk', 8),
#   ('almond milk', 5),
#   ('creme', 4),
#   ('curd', 3),
#   ('soy milk', 2),
#   ('curds', 2),
#   ('creami', 1),
#   ('creamer', 1),
#   ('oat milk', 1),
#   ('creamy', 1),
#   ('goat milk', 1)],
#  'fats': [('olive oil', 4566),
#   ('butter', 1672),
#   ('vegetable oil', 348),
#   ('oil', 266),
#   ('gelatin', 52),
#   ('margarine', 41),
#   ('shortening', 26),
#   ('lard', 5),
#   ('sesame oil', 4),
#   ('peanut oil', 4),
#   ('gravy', 3),
#   ('lecithin', 1)],
#  'fruit': [('lemon', 1401),
#   ('plum', 366),
#   ('orange', 278),
#   ('cherry', 187),
#   ('grape', 105),
#   ('raisins', 85),
#   ('lime', 50),
#   ('strawberries', 49),
#   ('raspberries', 41),
#   ('cherries', 37),
#   ('pears', 33),
#   ('apricot', 27),
#   ('figs', 25),
#   ('avocado', 25),
#   ('coconut', 23),
#   ('apple', 22),
#   ('peaches', 20),
#   ('currants', 19),
#   ('grapes', 17),
#   ('fruit', 16),
#   ('blueberries', 15),
#   ('blackberries', 15),
#   ('apples', 14),
#   ('plums', 14),
#   ('fig', 13),
#   ('cranberries', 11),
#   ('pineapple', 11),
#   ('oranges', 10),
#   ('pear', 10),
#   ('cantaloupe', 9),
#   ('currant', 8),
#   ('peach', 8),
#   ('prunes', 8),
#   ('grapefruit', 8),
#   ('watermelon', 7),
#   ('mango', 7),
#   ('banana', 6),
#   ('cranberry', 6),
#   ('citron', 6),
#   ('bananas', 6),
#   ('apricots', 5),
#   ('nectarines', 5),
#   ('raspberry', 5),
#   ('juniper', 5),
#   ('pomegranate', 5),
#   ('honeydew', 4),
#   ('strawberry', 3),
#   ('date', 3),
#   ('lemonade', 2),
#   ('zinfandel', 2),
#   ('sorrel', 2),
#   ('kumquats', 2),
#   ('tangerine', 2),
#   ('marrons', 1),
#   ('kiwi', 1),
#   ('fruits', 1),
#   ('mincemeat', 1),
#   ('raspberri', 1),
#   ('dates', 1),
#   ('blackberry', 1),
#   ('clementine', 1),
#   ('mandarin', 1),
#   ('pineapples', 1),
#   ('huckleberries', 1)],
#  'vegetables': [('tomatoes', 2473),
#   ('parsley', 1746),
#   ('onions', 1489),
#   ('onion', 1223),
#   ('red pepper', 962),
#   ('tomato', 873),
#   ('mushrooms', 719),
#   ('spinach', 589),
#   ('vegetable', 502),
#   ('carrots', 429),
#   ('celery', 428),
#   ('zucchini', 340),
#   ('shallots', 316),
#   ('corn', 221),
#   ('eggplant', 215),
#   ('potatoes', 203),
#   ('broccoli', 192),
#   ('peas', 188),
#   ('asparagus', 176),
#   ('arugula', 160),
#   ('red peppers', 138),
#   ('chives', 128),
#   ('salad', 109),
#   ('artichoke', 108),
#   ('leeks', 106),
#   ('mushroom', 92),
#   ('squash', 84),
#   ('green beans', 72),
#   ('kale', 71),
#   ('chard', 70),
#   ('potato', 68),
#   ('shiitake', 66),
#   ('butternut squash', 62),
#   ('cilantro', 52),
#   ('cabbage', 48),
#   ('escarole', 47),
#   ('cauliflower', 46),
#   ('artichokes', 46),
#   ('radicchio', 43),
#   ('romaine', 43),
#   ('ginger', 42),
#   ('vegetables', 39),
#   ('green pepper', 39),
#   ('cucumber', 38),
#   ('artichok', 33),
#   ('salata', 32),
#   ('truffle', 31),
#   ('lettuce', 30),
#   ('avocado', 25),
#   ('pumpkin', 23),
#   ('chili peppers', 22),
#   ('coriander', 20),
#   ('pea', 19),
#   ('pimentos', 16),
#   ('beets', 16),
#   ('watercress', 16),
#   ('sweet potatoes', 15),
#   ('endive', 14),
#   ('radishes', 13),
#   ('eggplants', 13),
#   ('green bean', 11),
#   ('sprouts', 10),
#   ('pimento', 10),
#   ('chili pepper', 8),
#   ('edamame', 8),
#   ('sweet pepper', 7),
#   ('parsnips', 7),
#   ('yellow peppers', 7),
#   ('iceberg', 6),
#   ('truffles', 6),
#   ('pickled', 5),
#   ('collard', 5),
#   ('carrot', 5),
#   ('haricots', 4),
#   ('veggies', 4),
#   ('palm', 3),
#   ('chervil', 3),
#   ('pickles', 3),
#   ('yams', 2),
#   ('veggie', 2),
#   ('beet', 2),
#   ('okra', 2),
#   ('arrowroot', 2),
#   ('cucumbers', 2),
#   ('pickling', 1),
#   ('pickle', 1),
#   ('turnips', 1),
#   ('veget', 1),
#   ('corned', 1),
#   ('radish', 1),
#   ('turnip', 1)],
#  'nuts': [('pinenuts', 252),
#   ('almonds', 172),
#   ('walnuts', 95),
#   ('almond', 94),
#   ('hazelnuts', 65),
#   ('butternut', 62),
#   ('pecans', 38),
#   ('nuts', 35),
#   ('pistachios', 27),
#   ('chestnuts', 14),
#   ('walnut', 14),
#   ('hazelnut', 11),
#   ('pistachio', 8),
#   ('chestnut', 7),
#   ('cashews', 6),
#   ('pecan', 5),
#   ('peanut', 4),
#   ('cashew', 3),
#   ('peanuts', 1),
#   ('macadamia', 1)],
#  'legumes': [('beans', 378),
#   ('peas', 188),
#   ('bean', 33),
#   ('pistachios', 27),
#   ('lentils', 24),
#   ('kidney', 23),
#   ('soy', 23),
#   ('garbanzo', 19),
#   ('pea', 19),
#   ('navy beans', 13),
#   ('pistachio', 8),
#   ('lima', 7),
#   ('pinto', 6),
#   ('black beans', 5),
#   ('lentil', 3)],
#  'sugars': [('sugar', 1309),
#   ('vanilla', 326),
#   ('chocolate', 211),
#   ('honey', 131),
#   ('powdered sugar', 69),
#   ('ladyfingers', 40),
#   ('ice', 36),
#   ('candied', 28),
#   ('syrup', 25),
#   ('pastry', 23),
#   ('sprinkles', 13),
#   ('pie', 12),
#   ('sweetened', 12),
#   ('maple', 8),
#   ('candy', 7),
#   ('tart', 7),
#   ('glace', 4),
#   ('molasses', 4),
#   ('sweeten', 3),
#   ('marshmallows', 3),
#   ('puff', 3),
#   ('caramel', 2),
#   ('frosting', 1),
#   ('glaze', 1),
#   ('toffee', 1),
#   ('gingersnap', 1),
#   ('icing', 1),
#   ('sweetener', 1),
#   ('pies', 1),
#   ('butterscotch', 1),
#   ('peppermint', 1),
#   ('fudge', 1)],
#  'sauces': [('marinara', 231),
#   ('pesto', 199),
#   ('marsala', 105),
#   ('sherry', 78),
#   ('alfredo', 68),
#   ('worcestershire', 60),
#   ('ragu', 28),
#   ('soy sauce', 21),
#   ('salsa', 13),
#   ('curry', 9),
#   ('tapenade', 5),
#   ('aioli', 3),
#   ('cannoli', 3),
#   ('tahini', 1),
#   ('chutney', 1),
#   ('applesauce', 1)],
#  'seasoning': [('pepper', 5395),
#   ('salt', 4822),
#   ('garlic', 4173),
#   ('basil', 2005),
#   ('oregano', 987),
#   ('lemon juice', 692),
#   ('thyme', 524),
#   ('rosemary', 506),
#   ('vanilla', 326),
#   ('capers', 308),
#   ('sage', 277),
#   ('bay', 274),
#   ('fennel', 253),
#   ('nutmeg', 231),
#   ('chocolate', 211),
#   ('peppers', 179),
#   ('mint', 169),
#   ('cinnamon', 126),
#   ('dressing', 123),
#   ('dijon', 107),
#   ('cocoa', 106),
#   ('paprika', 89),
#   ('extract', 72),
#   ('cayenne', 65),
#   ('marjoram', 62),
#   ('herbs', 53),
#   ('cilantro', 52),
#   ('tarragon', 48),
#   ('ginger', 42),
#   ('anise', 41),
#   ('mustard', 39),
#   ('saffron', 37),
#   ('cumin', 37),
#   ('peppercorns', 36),
#   ('flavored', 34),
#   ('lime juice', 31),
#   ('chile', 30),
#   ('cloves', 30),
#   ('mayonnaise', 25),
#   ('dill', 24),
#   ('clove', 23),
#   ('vinaigrette', 23),
#   ('jalapeno', 20),
#   ('coriander', 20),
#   ('salted', 17),
#   ('pimentos', 16),
#   ('watercress', 16),
#   ('herb', 14),
#   ('ketchup', 14),
#   ('herbes', 13),
#   ('sesame seeds', 13),
#   ('pepperoncini', 13),
#   ('allspice', 12),
#   ('jam', 11),
#   ('chiles', 11),
#   ('pimento', 10),
#   ('poppy', 9),
#   ('cardamom', 9),
#   ('spicy', 7),
#   ('horseradish', 6),
#   ('nutmegs', 6),
#   ('caper', 5),
#   ('sunflower', 4),
#   ('sesame', 4),
#   ('spice', 3),
#   ('spices', 3),
#   ('mace', 2),
#   ('savory', 2),
#   ('relish', 2),
#   ('rhubarb', 2),
#   ('turmeric', 2),
#   ('peppercorn', 2),
#   ('marinade', 2),
#   ('caraway', 2),
#   ('arrowroot', 2),
#   ('rosemari', 2),
#   ('flavoring', 1),
#   ('miso', 1),
#   ('masala', 1),
#   ('tamari', 1),
#   ('herbed', 1),
#   ('flax', 1)]}

# %%
def transform_ingredients(test_ingredients, italian_kb, ingredients_kb):
    transformed_ingredients = []
    og_simplified_ingredients = []
    counter = Counter()
    
    test_grams = get_ngrams(test_ingredients)

    for i in test_grams:    
        match = False
        
        for g in i:        
            for category in ingredients_kb:
                ingredients_stemmed = [ps.stem(x) for x in ingredients_kb[category]]
                italian_stemmed = [ps.stem(x[0]) for x in italian_kb[category]]

                if ps.stem(g) in ingredients_stemmed:
                    og = g
                    new = g 
                      
                    if (len(italian_kb[category]) > counter[category]) and ps.stem(g) not in italian_stemmed[:2]:
                        new = italian_kb[category][counter[category]][0]
                        #og_simplified_ingredients.append(g)
                        #transformed_ingredients.append(italian_kb[category][counter[category]][0])
                        counter[category] += 1
                        #break
                        
                    if ps.stem(new) in [ps.stem(x) for x in transformed_ingredients]:
                        if (len(italian_kb[category]) > counter[category]):
                            counter[category] += 1
                            new = italian_kb[category][counter[category]][0]
                    
                    transformed_ingredients.append(new)
                    og_simplified_ingredients.append(og)
                    match = True
                    break
                    
            if match:
                break
                
        if not match:
            og_simplified_ingredients.append(i[0])
            transformed_ingredients.append(i[0])
            
    return transformed_ingredients, og_simplified_ingredients

# %%
og_ingredients, og_directions = main_parse('https://www.allrecipes.com/recipe/255865/slow-cooker-thai-curried-beef/',check="single")
# Out:
# https://www.allrecipes.com/recipe/255865/slow-cooker-thai-curried-beef/

# %%
test_ingredients = get_test_ingredients(og_ingredients)

# %%
test_ingredients
# Out:
# ['lean stew beef',
#  'salt',
#  'diced onion',
#  'garlic, minced',
#  '(13.5 ounce) can coconut milk',
#  'beef broth',
#  'red curry paste',
#  'lime juice',
#  'peanut oil',
#  'jalapeno chile peppers, seeded and minced',
#  'brown sugar',
#  'baby spinach',
#  'water',
#  'jasmine rice',
#  'fresh basil leaves (optional)']

# %%
transformed_ingredients, og_simplified_ingredients = transform_ingredients(test_ingredients, italian_kb, ingredients_kb)

# %%
transformed_ingredients
# Out:
# ['chicken',
#  'salt',
#  'tomatoes',
#  'pepper',
#  'milk',
#  'eggs',
#  'marinara',
#  'basil',
#  'olive oil',
#  'lemon juice',
#  'sugar',
#  'parsley',
#  'water',
#  'pasta',
#  'rosemary']

# %%
og_simplified_ingredients
# Out:
# ['beef',
#  'salt',
#  'onion',
#  'garlic',
#  'coconut milk',
#  'beef',
#  'curry',
#  'lime juice',
#  'peanut oil',
#  'jalapeno',
#  'sugar',
#  'spinach',
#  'water',
#  'rice',
#  'basil']

# %%
# takes our created italian ingredients KB and list of all recipes, writes dict of italian ingredients + frequencies divided by food group to json
def get_italian_ingredients_dict(italian_json, all_recipes):
    # import stop words
    stop_words = set(stopwords.words('english'))
    
    # create PorterStemmer object for stemming words
    ps = PorterStemmer()
    
    # import italian ingredients KB (dict of food categories)
    with open(italian_json) as json_file:
        ingredients_kb = json.load(json_file)
        
    # import all_recipes json, get ingredients from only italian recipes
    italian = get_italian_ingredients(all_recipes)
    
    # calculate dict of italian ingredients + frequencies (keys=food categories)
    italian_kb = get_italian_freq(italian, ingredients_kb)
    
    # write dict to json file
    with open('italian_freq.json', 'w') as f:
        json.dump(italian_kb, f)
        
    return italian_kb

# %%
# takes list of og_ingredients (from main_parse) + name of italian ingredients json file, returns list of transformed ingredients
def cuisine_to_italian_ingredients(og_ingredients, italian_kb, ingredients_kb):
    # retrieve dict of italian ingredients + frequencies from json
    with open(italian_kb) as json_file:
        italian_kb = json.load(json_file)
        
    # get ingredients from recipe being transformed
    test_ingredients = get_test_ingredients(og_ingredients)
    
    # gets list of transformed ingredients
    transformed_ingredients, og_simplified_ingredients = transform_ingredients(test_ingredients, italian_kb, ingredients_kb)
    
    return transformed_ingredients, og_simplified_ingredients

# %%
def cuisine_to_italian_directions(og_simplified_ingredients, og_directions, transformed_ingredients):    
    new_directions = '@'.join(og_directions)
    
    print(og_directions)
    
    for i in og_simplified_ingredients:
        if i in new_directions:
            new_directions = new_directions.replace(i, transformed_ingredients[og_simplified_ingredients.index(i)])

    new_directions = new_directions.split('@')
                           
    return new_directions

# %%
cuisine_to_italian_directions(og_simplified_ingredients, og_directions, transformed_ingredients)
# Out:
# ['Preheat a large skillet over medium-high heat. Cook and stir beef until browned, about 2 minutes per side. Drain excess grease. Transfer beef to a 4-quart slow cooker and sprinkle with salt.\n                            ', 'Combine onion and garlic in the same skillet over medium-high heat; saute until tender, about 5 minutes. Add to beef in the slow cooker.\n                            ', 'Stir coconut milk, beef broth, red curry paste, lime juice, peanut oil, jalapeno chile peppers, and brown sugar into the slow cooker.\n                            ', 'Cover and cook on Low until flavors combine, 6 to 10 hours.\n                            ', 'Bring water and rice to a boil in a saucepan. Reduce heat to medium-low, cover, and simmer until rice is tender and liquid has been absorbed, 20 to 25 minutes.\n                            ', 'Stir spinach into the slow cooker and cook until wilted, about 15 minutes. Serve beef mixture over rice and garnish with basil leaves.\n                            ']
# ['Preheat a large skillet over medium-high heat. Cook and stir chicken until browned, about 2 minutes per side. Drain excess grease. Transfer chicken to a 4-quart slow cooker and sprinkle with salt.\n                            ',
#  'Combine tomatoes and pepper in the same skillet over medium-high heat; saute until tender, about 5 minutes. Add to chicken in the slow cooker.\n                            ',
#  'Stir milk, chicken broth, red marinara paste, rosemary, olive oil, lemon juice chile peppers, and brown sugar into the slow cooker.\n                            ',
#  'Cover and cook on Low until flavors combine, 6 to 10 hours.\n                            ',
#  'Bring water and pasta to a boil in a saucepan. Reduce heat to medium-low, cover, and simmer until pasta is tender and liquid has been absorbed, 20 to 25 minutes.\n                            ',
#  'Stir parsley into the slow cooker and cook until wilted, about 15 minutes. Serve chicken mixture over pasta and garnish with rosemary leaves.\n                            ']

# %%
og_ingredients, og_directions = main_parse('https://www.allrecipes.com/recipe/236805/king-ranch-chicken-casserole/',check="single")
# Out:
# https://www.allrecipes.com/recipe/236805/king-ranch-chicken-casserole/

# %%
get_test_ingredients(og_ingredients)
# Out:
# ['vegetable oil',
#  'white onion, diced',
#  'red bell pepper, diced',
#  'green bell pepper, diced',
#  '(10.75 ounce) can condensed cream of mushroom soup',
#  '(10.75 ounce) can condensed cream of chicken soup',
#  '(10 ounce) can diced tomatoes with green chile peppers (such as RO*TEL®)',
#  'chicken broth',
#  'sour cream',
#  'ground cumin',
#  'ancho chile powder',
#  'dried oregano',
#  'chipotle chile powder',
#  'cooked chicken, torn into shreds or cut into chunks',
#  'shredded Cheddar cheese',
#  'corn tortillas, cut into quarters']

# %%
og_directions
# Out:
# ['Preheat oven to 350 degrees F (175 degrees C).\n                            ',
#  'Heat oil in a large skillet over high heat. Saute onion, red bell pepper, and green bell pepper in hot oil until warmed through, about 2 minutes.\n                            ',
#  'Combine onion-pepper mixture, cream of mushroom soup, cream of chicken soup, diced tomatoes, chicken broth, sour cream, cumin, ancho chile powder, oregano, and chipotle chile powder together in a large bowl and stir until sauce is well-combined.\n                            ',
#  'Spread a few tablespoons of the sauce in the bottom of a 9x13-inch baking dish. Spread 1/2 the chicken over the sauce. Spread about half the sauce over the chicken and top with 1/3 the cheese. Spread a layer of tortillas over the cheese. Spread remaining 1/2 the chicken over the tortillas, and top with almost all of the remaining sauce, reserving 1/2 cup sauce. Top with 1/3 the cheese, remaining tortillas, the reserved 1/2 cup sauce, and remaining 1/3 cheese.\n                            ',
#  'Bake casserole in the preheated oven until bubbling, about 40 minutes. Increase the oven temperature to broil. Broil the casserole until top is golden, 2 to 3 minutes more.\n                            ']

# %%
test.replace('tuna','chicken')
# Out:
# 'Preheat oven to 350 degrees F (175 degrees C). Line a baking sheet with aluminum foil, and spray with cooking spray.\n                            In a large bowl, thoroughly mix the chicken, bread crumbs, zucchini, green pepper, onion, green onions, garlic, jalapeno pepper, cottage cheese, sour cream, 2 eggs, lime juice, dried basil, pepper, and salt.\n                            Beat 2 eggs in a shallow bowl, and place the cornmeal on a plate.\n                            Scoop up about 1/4 cup of the chicken mixture, and gently form it into a compact patty. Dip both sides of each cake into beaten egg and then press into cornmeal, and place the cakes onto the prepared baking sheet. Spray the tops of the cakes with cooking oil spray.\n                            Bake in the preheated oven until the tops of the cakes are beginning to brown, about 20 minutes. Flip each cake, spray with cooking spray, and bake until the cakes are cooked through and lightly browned, about 20 more minutes.\n                            '

# %%
with open('train.json') as json_file:
    all_recipes = json.load(json_file)
